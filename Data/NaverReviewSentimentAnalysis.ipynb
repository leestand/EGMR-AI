# %% [markdown]
# # 네이버 리뷰 감정분석

# %% [markdown]
# ## 구글 드라이브 마운트

# %%
import json
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 전체 데이터셋 로드

# %%
# 데이터 로드
# JSON 파일 읽어오기
with open('/content/drive/MyDrive/NaverCrawlingData/final_final_final_dataset.json', 'r') as f:
    data = json.load(f)

# 빈 리스트 생성 (추출된 데이터를 저장하기 위한)
df_data = []

# 각 store에 대해 반복
for store in data:
    store_id = store['store_id']
    store_name = store['store_info']['store_name']

    # 각 review에 대해 반복
    for review in store['reviews']:
        text = review['text']
        df_data.append([store_id, store_name, text])

# DataFrame 생성
df = pd.DataFrame(df_data, columns=['store_id', 'store_name', 'text'])

df
# Out:
#          store_id store_name  \
# 0      1582818366   퀸즈가든 양재점
# 1      1582818366   퀸즈가든 양재점
# 2      1582818366   퀸즈가든 양재점
# 3      1582818366   퀸즈가든 양재점
# 4      1582818366   퀸즈가든 양재점
# ...           ...        ...
# 27795    13150444         난랑
# 27796    13150444         난랑
# 27797    13150444         난랑
# 27798    13150444         난랑
# 27799    13150444         난랑
#
#                                                     text
# 0      양재역 맛집 퀸즈가든에서 특별한 식사를 즐겼어요! 샤브샤브와 월남쌈이 무한리필로 제...
# 1      고기와 야채 상태가 굉장히 좋고 무한리필이라는 점이 정말 좋습니다. 무한리필임에도 ...
# 2                             맥주 무제한 리필... 감동에 감동 하고 갑니다
# 3                                     가성비 좋고 야채가 신선해요!!!
# 4      디너세트 무한리필로 먹었는데 진짜 맛있게 배터지게 먹고 왔어요! 채소도 너무 신선하...
# ...                                                  ...
# 27795                                            음식 맛있어요
# 27796                                               좋아요
# 27797                                              맛있어요~
# 27798                                               좋아요
# 27799                                  짜장면과 짬뽕이 반찬도 맛있어요
#
# [27800 rows x 3 columns]

# %%
print(df[df['text'].str.isspace()])
print(df.isnull().sum())
# Out:
# Empty DataFrame
# Columns: [store_id, store_name, text]
# Index: []
# store_id      0
# store_name    0
# text          0
# dtype: int64

# %%
# 결측치 제거
df = df[df['text'] != '']
df.reset_index(drop=True, inplace=True)
df
# Out:
#          store_id store_name  \
# 0      1582818366   퀸즈가든 양재점
# 1      1582818366   퀸즈가든 양재점
# 2      1582818366   퀸즈가든 양재점
# 3      1582818366   퀸즈가든 양재점
# 4      1582818366   퀸즈가든 양재점
# ...           ...        ...
# 26866    13150444         난랑
# 26867    13150444         난랑
# 26868    13150444         난랑
# 26869    13150444         난랑
# 26870    13150444         난랑
#
#                                                     text
# 0      양재역 맛집 퀸즈가든에서 특별한 식사를 즐겼어요! 샤브샤브와 월남쌈이 무한리필로 제...
# 1      고기와 야채 상태가 굉장히 좋고 무한리필이라는 점이 정말 좋습니다. 무한리필임에도 ...
# 2                             맥주 무제한 리필... 감동에 감동 하고 갑니다
# 3                                     가성비 좋고 야채가 신선해요!!!
# 4      디너세트 무한리필로 먹었는데 진짜 맛있게 배터지게 먹고 왔어요! 채소도 너무 신선하...
# ...                                                  ...
# 26866                                            음식 맛있어요
# 26867                                               좋아요
# 26868                                              맛있어요~
# 26869                                               좋아요
# 26870                                  짜장면과 짬뽕이 반찬도 맛있어요
#
# [26871 rows x 3 columns]

# %%
# store_id의 고유한 개수 세기
unique_store_count = df['store_id'].nunique()

# 결과 출력
print(f"unique한 store_id의 개수: {unique_store_count}")
# Out:
# unique한 store_id의 개수: 134

# %% [markdown]
# # 감정분석
# - 필요 패키지 다운로드

# %%
# !pip install -Uqq torch transformers datasets pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 85.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 95.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 92.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# fastai 2.7.17 requires torch<2.5,>=1.10, but you have torch 2.5.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# torchaudio 2.4.1+cu121 requires torch==2.4.1, but you have torch 2.5.0 which is incompatible.
# torchvision 0.19.1+cu121 requires torch==2.4.1, but you have torch 2.5.0 which is incompatible.

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset
from torch.utils.data import DataLoader
from tqdm import tqdm

import pandas as pd

# %% [markdown]
# ## 허깅페이스 korean-sentiment 모델 불러오기

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("WhitePeak/bert-base-cased-Korean-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("WhitePeak/bert-base-cased-Korean-sentiment")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/895 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/711M [00:00<?, ?B/s]

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="WhitePeak/bert-base-cased-Korean-sentiment")

# %% [markdown]
# ## Mecab 설치

# %%
# word2vec 모듈 불러오기 / mecab import
from gensim.models import Word2Vec
from tqdm import tqdm

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91 (from 1)
# Receiving objects: 100% (138/138), 1.72 MiB | 16.11 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab_light_220429.sh
# Out:
# Installing konlpy.....
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 50.7 MB/s eta 0:00:00
# Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 28.8 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2024-10-23 07:37:09--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.25, 104.192.142.24, 104.192.142.26, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.142.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNFHWE7EWV&Signature=mC8GetwU77gybh%2FpKoFwdhMbpkc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEFAaCXVzLWVhc3QtMSJIMEYCIQDRZ2L3JIp0m9mWKxrXzXVLSkYMkWGssXhPnGE2z4WKYwIhANTuvF7lSK%2FBzL72x56Gmi7Z3Q0eYKbCS1DLWXt%2FT1ERKrACCLn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQABoMOTg0NTI1MTAxMTQ2Igz65Nh5EpPqdE7mcl4qhAJkvvivkesNbfS0cxqUM5YWshPyKrZPSthdp9SOz7eKfXG9g%2FLkQA9KIRPIrON31sLcS4HyROsKi0OTAlt8Tkvz5wzEFglNG%2FYaUJQxoxPfBkQxXaX1gwCLMz%2BO98sQ4GXR7%2FiQ59ze4bm%2F5Te7B5QlQQRchV3kVVfXplupR4pA7G%2F5CGoMKHOEOowGxAnUmsPHmLqC2Lfk6yYcJ0Q6eWrliMNBYzKIGQEpx0qH%2FLUu5to8imNf5hKUgmv%2B9sHBJH3sqEvBvk%2BIC%2FipA6UDyZxvXMMeO%2FYSpIZjzoQzykzz0DgNz%2FrybDMgcz9fFCF%2BZsTSg7vXkEQUvJfe6o6ieTc0c%2Fmd8zDYyuK4BjqcAYcvpMUzGHcfKmhayYeUa9lvU3fmFjz53yogZHBtKQt8LoQxPsx6nAOQs5QQJEO3HwJgepgb4WB1AUup1AI401r7sKbXklHse%2F6KS6OYir33EZ2D5Y3OfrNV0kj986J0NPkGQIwF5HdinyKhLO3O2FFLjeZW2k9ZVAKOAiJ%2F9n%2FkmmxTcFmgwDcAnIK1hpWquo0ZeIwx2bLYSYFYaQ%3D%3D&Expires=1729670240 [following]
# --2024-10-23 07:37:09--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNFHWE7EWV&Signature=mC8GetwU77gybh%2FpKoFwdhMbpkc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEFAaCXVzLWVhc3QtMSJIMEYCIQDRZ2L3JIp0m9mWKxrXzXVLSkYMkWGssXhPnGE2z4WKYwIhANTuvF7lSK%2FBzL72x56Gmi7Z3Q0eYKbCS1DLWXt%2FT1ERKrACCLn%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQABoMOTg0NTI1MTAxMTQ2Igz65Nh5EpPqdE7mcl4qhAJkvvivkesNbfS0cxqUM5YWshPyKrZPSthdp9SOz7eKfXG9g%2FLkQA9KIRPIrON31sLcS4HyROsKi0OTAlt8Tkvz5wzEFglNG%2FYaUJQxoxPfBkQxXaX1gwCLMz%2BO98sQ4GXR7%2FiQ59ze4bm%2F5Te7B5QlQQRchV3kVVfXplupR4pA7G%2F5CGoMKHOEOowGxAnUmsPHmLqC2Lfk6yYcJ0Q6eWrliMNBYzKIGQEpx0qH%2FLUu5to8imNf5hKUgmv%2B9sHBJH3sqEvBvk%2BIC%2FipA6UDyZxvXMMeO%2FYSpIZjzoQzykzz0DgNz%2FrybDMgcz9fFCF%2BZsTSg7vXkEQUvJfe6o6ieTc0c%2Fmd8zDYyuK4BjqcAYcvpMUzGHcfKmhayYeUa9lvU3fmFjz53yogZHBtKQt8LoQxPsx6nAOQs5QQJEO3HwJgepgb4WB1AUup1AI401r7sKbXklHse%2F6KS6OYir33EZ2D5Y3OfrNV0kj986J0NPkGQIwF5HdinyKhLO3O2FFLjeZW2k9ZVAKOAiJ%2F9n%2FkmmxTcFmgwDcAnIK1hpWquo0ZeIwx2bLYSYFYaQ%3D%3D&Expires=1729670240
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.34.169, 3.5.13.187, 3.5.28.122, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.34.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.1s
#
# 2024-10-23 07:37:10 (10.7 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2024-10-23 07:39:24--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.25, 104.192.142.24, 104.192.142.26, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.142.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNP5KN4UFX&Signature=dXOBDwOXhlgvRQgrMOhvCrhPusM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEFAaCXVzLWVhc3QtMSJHMEUCIQDcRTouZVa5vE2vSCe9LnKxiv92xux27A2wzdWOEEEtAAIgR2%2ByKv19Le52L8D2AbzDZoYB06exrz8ipALmJv0af0IqsAIIuf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDAIV0EnRaaxG80nKaSqEAtlZ8efYUPmqoJ3j0ad5L5isjP2hDAZx0iolSi48KwvP9ox5Nn8F%2BElRhbV45O086XEheol3w8tTRXUfSLw8fnlvphLqSePsEO%2B%2Bdy2tXT8ZxSQ%2BJ6gvBay2fWjL%2FvGUAG2P9kiGcxP2HkY0hsKgj4FQXyDxzeM7ChyzLxc6DygwDevEF5G1aCHJXz8eSbjAb8HriCPlJnjpf7OZIFPo0l%2BkpGur5dXyET%2F%2FdBm%2Fvh7x2idYgANhBwMWIqwod6KeSOu3%2BUqncqHfOgyMPPgZ5ullYtGv%2FGQaRlr1snOrLfLn%2FCrKtsBvStdSW7KI%2BH4FBcgCnfM8OiFGET4hen0vQREn0H5NMJHO4rgGOp0BrALHY1req3auU7Um6Yk7rb78LvdJ%2Bx49l7qsK8BJubum4q2tMYF2ncFqMPEs8fks47x755jgWYivWxCoBfFnUD3drh2Aa9eLtLNsTnPVABzcT5vUJ879BLARKQJnRKQQVT4%2B%2BxRKTtUXqPoVX3QZbwI0A5wL7zdJOyifUevUNOz%2FqxB345M8JLcYpO1ftfE9HXd2qMAjxxDvYljCJg%3D%3D&Expires=1729670681 [following]
# --2024-10-23 07:39:25--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNP5KN4UFX&Signature=dXOBDwOXhlgvRQgrMOhvCrhPusM%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEFAaCXVzLWVhc3QtMSJHMEUCIQDcRTouZVa5vE2vSCe9LnKxiv92xux27A2wzdWOEEEtAAIgR2%2ByKv19Le52L8D2AbzDZoYB06exrz8ipALmJv0af0IqsAIIuf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDAIV0EnRaaxG80nKaSqEAtlZ8efYUPmqoJ3j0ad5L5isjP2hDAZx0iolSi48KwvP9ox5Nn8F%2BElRhbV45O086XEheol3w8tTRXUfSLw8fnlvphLqSePsEO%2B%2Bdy2tXT8ZxSQ%2BJ6gvBay2fWjL%2FvGUAG2P9kiGcxP2HkY0hsKgj4FQXyDxzeM7ChyzLxc6DygwDevEF5G1aCHJXz8eSbjAb8HriCPlJnjpf7OZIFPo0l%2BkpGur5dXyET%2F%2FdBm%2Fvh7x2idYgANhBwMWIqwod6KeSOu3%2BUqncqHfOgyMPPgZ5ullYtGv%2FGQaRlr1snOrLfLn%2FCrKtsBvStdSW7KI%2BH4FBcgCnfM8OiFGET4hen0vQREn0H5NMJHO4rgGOp0BrALHY1req3auU7Um6Yk7rb78LvdJ%2Bx49l7qsK8BJubum4q2tMYF2ncFqMPEs8fks47x755jgWYivWxCoBfFnUD3drh2Aa9eLtLNsTnPVABzcT5vUJ879BLARKQJnRKQQVT4%2B%2BxRKTtUXqPoVX3QZbwI0A5wL7zdJOyifUevUNOz%2FqxB345M8JLcYpO1ftfE9HXd2qMAjxxDvYljCJg%3D%3D&Expires=1729670681
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.120.145, 52.216.241.20, 54.231.201.209, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.120.145|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M   101MB/s    in 0.5s
#
# 2024-10-23 07:39:25 (101 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/v0.6.0/scripts/mecab.sh)
# https://github.com/konlpy/konlpy/issues/395#issue-1099168405 - 2022.01.11
# Done
# Install mecab-python
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.
# light 버전 작성 : Dogdriip님 ( https://github.com/Dogdriip )
# 문제를 해결해주신 combacsa님 감사합니다.

# %%
from konlpy.tag import Mecab

mecab = Mecab()
text = "아버지가방에들어가신다"

# 1. 형태소 추출
morphs = mecab.morphs(text)
print(f"형태소: {morphs}")

# 2. 형태소 + 품사 태깅
pos = mecab.pos(text)
print(f"품사 태깅: {pos}")

# 3. 명사만 추출
nouns = mecab.nouns(text)
print(f"명사: {nouns}")
# Out:
# 형태소: ['아버지', '가', '방', '에', '들어가', '신다']
# 품사 태깅: [('아버지', 'NNG'), ('가', 'JKS'), ('방', 'NNG'), ('에', 'JKB'), ('들어가', 'VV'), ('신다', 'EP+EC')]
# 명사: ['아버지', '방']

# %% [markdown]
# # ABSA 모델

# %%
# 사전 정의된 키워드로 문장에서 특정 측면 추출
aspects = {
    "가성비": ["무제한", "가성비", "가격", "저렴", "양", "착한가격", "가격대비", "거성비", "가격좋고", "사악",
    "가격대비퀄", "음식량", "음식양", "양", "비싼", "싼", "가격대비", "가격 대비", "값",
    "값어치", "혜자", "창렬", "부족", "넉넉", "적은", "많은", "푸짐", "평균 가격 보다",
    "돈 아까운", "저렴", "고렴", "꽉찬", "퀄리티", "적은", "무료", "추가금", "보기보다",
    "배 터지는", "배가 터지는", "무제한", "싸다", "무한리필"],

    "청결도": ["청결", "깨끗", "머리카락",
    "파리", "벌레", "먼지", "얼룩", "화장실", "덜 닦인", "끈적", "주방", "깔끔", "냄새",
    "위생", "비위생", "불쾌", "쾌적", "덜 닦인", "벌레", "오픈 키친", "오픈된 키친",
    "주방 오픈", "오픈된 주방", "눈썹", "털", "가게", "행주", "걸레", "위생 상태",
    "위생상태", "지저분", "모기"],

    "재방문": ["재방문", "재방문 의사", "단골", "또 올게용", "또올게용", "다음", "또간집",
    "또올게요", "또 회식", "두번째", "2번째 방문", "주기적으로", "단골집", "재방문의사",
    "다시 갈", "예정", "일 만에", "개월 만에", "달 만에", "년 만에", "다음에", "담에",
    "또 올", "다시 찾고", "자주", "다음 번에"],

    "속도": ["웨이팅", "빨리", "회전율", "회전률",
    "속도", "서빙", "사람", "정신없", "바로", "사람이 많", "박작박작", "북적북적", "평일인데도",
    "평일에도", "예약", "좌석", "대기", "만석"],

    "분위기":["분위기", "인테리어", "서비스", "기념일",
    "특별한 날", "고급", "조용", "차분", "데이트", "데이또코스", "깔끔한", "미슐랭", "플레이팅",
    "조용", "시끌", "와인", "비주얼", "모임", "연말", "크리스마스", "소음", "음식 셋팀",
    "단란한", "차분", "조용", "모시고 방문", "아늑", "중요한 손님", "세련된", "발렛",
    "생일", "생일파티", "프라이빗", "아기자기", "대화하기", "시끄러운", "시끌벅적", "특별한", "섬세"]
}

sentence = '무한리필에 굶주린 자들이여. 이리오시게. 냉큼오시게. 앉자마자 무자비하게 셋팅된 고기무덤과 야채무덤 그리고 라이스페이퍼와 소스4종을 구경하고 있으면 오리구이도 나오는 광경을 목격. 디너스페셜무제한퀸즈세트 시켯고 무한리필메뉴 시킨사람 한정 여기에 6천원 돈더내면 테라생맥주 무제한이라 오늘은 여기에 눕자 심정으로 술이 술술들어감ㅋㅋ 월남쌈으로 애피타이저 시작. 샤브샤브국물로 뜨끈하게 몸 데우고 고기넣어 흡입하다가 이젠 구워먹기로 전략변경. 소스찍어 먹으니 더 존맛.배에 기름칠하다 약간 느끼할때쯤 생맥 가져와서 칼국수와 함께 먹으면 또 다시 마라톤 시작ㅋㅋㅋ 집에 가기 아쉬울때쯤 밥이랑 야채 참기름 그리고 계란까지 가져와서 야채죽 해먹으면 그제서야 집에 가야하는건가싶은 여기는 퀸즈가든. 다들 배부르게한번 잡솨봐'
aspect_sentiments = {}

# 각 키워드의 주변 문맥만 추출하여 감정 분석 수행
for aspect, keywords in aspects.items():
    for keyword in keywords:
        if keyword in sentence:
            # 키워드가 포함된 문맥 추출 (키워드 주변의 단어들을 포함)
            context_start = max(0, sentence.index(keyword) - 5)  # 키워드 앞에 5글자
            context_end = min(len(sentence), sentence.index(keyword) + len(keyword) + 5)  # 키워드 뒤에 5글자
            context = sentence[context_start:context_end]

            # 1. Mecab을 사용해 형태소 분석 및 명사, 동사만 추출
            morphs = mecab.morphs(context)  # 형태소 추출
            filtered_context = " ".join(morphs)  # 필터링된 텍스트

            # 토큰화 및 감정 분석 수행
            inputs = tokenizer(filtered_context, return_tensors='pt', padding=True, truncation=True, max_length=512)
            with torch.no_grad():
                logits = model(**inputs).logits

            # 감정 분류 (0: 부정, 1: 긍정)
            predicted_class = torch.argmax(logits, dim=1).item()
            sentiment_label = "긍정" if predicted_class == 1 else "부정"
            aspect_sentiments[aspect] = sentiment_label

# 결과 출력
for aspect, sentiment in aspect_sentiments.items():
    print(f"측면: {aspect}, 감정: {sentiment}")
# Out:
# 측면: 가성비, 감정: 부정
# 측면: 속도, 감정: 부정

# %%
# 사전 정의된 키워드와 그에 해당하는 측면
aspect_keywords = {
    "가성비": ["가성비", "가격", "저렴", "양", "착한가격", "가격대비", "거성비", "가격좋고", "사악",
    "가격대비퀄", "음식량", "음식양", "양", "비싼", "싼", "가격대비", "가격 대비", "값",
    "값어치", "혜자", "창렬", "부족", "넉넉", "적은", "많은", "푸짐", "평균 가격 보다",
    "돈 아까운", "저렴", "고렴", "꽉찬", "퀄리티", "적은", "무료", "추가금", "보기보다",
    "배 터지는", "배가 터지는", "무제한", "싸다", "무한리필"],

    "청결도": ["청결", "깨끗", "머리카락",
    "파리", "벌레", "먼지", "얼룩", "화장실", "덜 닦인", "끈적", "주방", "깔끔", "냄새",
    "위생", "비위생", "불쾌", "쾌적", "덜 닦인", "벌레", "오픈 키친", "오픈된 키친",
    "주방 오픈", "오픈된 주방", "눈썹", "털", "가게", "행주", "걸레", "위생 상태",
    "위생상태", "지저분", "모기"],

    "재방문": ["재방문", "재방문 의사", "단골", "또 올게용", "또올게용", "다음", "또간집",
    "또올게요", "또 회식", "두번째", "2번째 방문", "주기적으로", "단골집", "재방문의사",
    "다시 갈", "예정", "일 만에", "개월 만에", "달 만에", "년 만에", "다음에", "담에",
    "또 올", "다시 찾고", "자주", "다음 번에"],

    "속도": ["웨이팅", "빨리", "회전율", "회전률",
    "속도", "서빙", "사람", "정신없", "바로", "사람이 많", "박작박작", "북적북적", "평일인데도",
    "평일에도", "예약", "좌석", "대기", "만석"],

    "분위기":["분위기", "인테리어", "서비스", "기념일",
    "특별한 날", "고급", "조용", "차분", "데이트", "데이또코스", "깔끔한", "미슐랭", "플레이팅",
    "조용", "시끌", "와인", "비주얼", "모임", "연말", "크리스마스", "소음", "음식 셋팀",
    "단란한", "차분", "조용", "모시고 방문", "아늑", "중요한 손님", "세련된", "발렛",
    "생일", "생일파티", "프라이빗", "아기자기", "대화하기", "시끄러운", "시끌벅적", "특별한", "섬세"]
}

# %%
# 가게별 키워드들의 긍정/부정 카운트를 저장할 딕셔너리
store_aspect_sentiments = {}

# 리뷰 별로 반복
for index, row in df.iterrows():
    store_id = row['store_id']
    store_name = row['store_name']
    sentence = row['text']

    # 해당 store_id가 딕셔너리에 없으면 초기화
    if store_id not in store_aspect_sentiments:
        store_aspect_sentiments[store_id] = {
            'store_name': store_name,
            'aspect_sentiments': {aspect: {'positive': 0, 'negative': 0} for aspect in aspect_keywords}
        }

    aspect_sentiments = store_aspect_sentiments[store_id]['aspect_sentiments']

    # 키워드별 감정 분석 수행
    for aspect, keywords in aspect_keywords.items():
        for keyword in keywords:
            if keyword in sentence:
                # 문맥 추출 및 감정 분석 (기존 방식)
                context_start = max(0, sentence.index(keyword) - 5)
                context_end = min(len(sentence), sentence.index(keyword) + len(keyword) + 5)
                context = sentence[context_start:context_end]

                morphs = mecab.morphs(context)
                filtered_context = " ".join(morphs)

                inputs = tokenizer(filtered_context, return_tensors='pt', padding=True, truncation=True, max_length=512)
                with torch.no_grad():
                    logits = model(**inputs).logits

                predicted_class = torch.argmax(logits, dim=1).item()
                sentiment_label = "긍정" if predicted_class == 1 else "부정"

                # 긍정/부정 카운트 누적
                if sentiment_label == "긍정":
                    aspect_sentiments[aspect]['positive'] += 1
                else:
                    aspect_sentiments[aspect]['negative'] += 1

# 결과 출력
for store_id, sentiment_data in store_aspect_sentiments.items():
    print(f"가게 ID: {store_id}, 가게 이름: {sentiment_data['store_name']}")
    for aspect, counts in sentiment_data['aspect_sentiments'].items():
        print(f"  측면: {aspect}, 긍정 개수: {counts['positive']}, 부정 개수: {counts['negative']}")
# Out:
# 가게 ID: 1582818366, 가게 이름: 퀸즈가든 양재점
#   측면: 가성비, 긍정 개수: 172, 부정 개수: 116
#   측면: 청결도, 긍정 개수: 31, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 35, 부정 개수: 8
#   측면: 속도, 긍정 개수: 6, 부정 개수: 10
#   측면: 분위기, 긍정 개수: 17, 부정 개수: 17
# 가게 ID: 37233088, 가게 이름: 갈비사랑 양재본점
#   측면: 가성비, 긍정 개수: 22, 부정 개수: 47
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 10
#   측면: 속도, 긍정 개수: 2, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 29, 부정 개수: 18
# 가게 ID: 38264349, 가게 이름: 한양돈까스
#   측면: 가성비, 긍정 개수: 55, 부정 개수: 73
#   측면: 청결도, 긍정 개수: 6, 부정 개수: 9
#   측면: 재방문, 긍정 개수: 9, 부정 개수: 9
#   측면: 속도, 긍정 개수: 11, 부정 개수: 19
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 4
# 가게 ID: 1113983640, 가게 이름: 탐라순대국감자탕 양재역직영점
#   측면: 가성비, 긍정 개수: 85, 부정 개수: 59
#   측면: 청결도, 긍정 개수: 67, 부정 개수: 15
#   측면: 재방문, 긍정 개수: 65, 부정 개수: 10
#   측면: 속도, 긍정 개수: 4, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 15, 부정 개수: 9
# 가게 ID: 32254662, 가게 이름: 한국순대 본점
#   측면: 가성비, 긍정 개수: 42, 부정 개수: 72
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 7
#   측면: 재방문, 긍정 개수: 10, 부정 개수: 2
#   측면: 속도, 긍정 개수: 11, 부정 개수: 17
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 1
# 가게 ID: 1427943416, 가게 이름: 고려향
#   측면: 가성비, 긍정 개수: 6, 부정 개수: 20
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 3
#   측면: 속도, 긍정 개수: 5, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 7
# 가게 ID: 1879800911, 가게 이름: 쿠니라멘
#   측면: 가성비, 긍정 개수: 17, 부정 개수: 17
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 7, 부정 개수: 2
#   측면: 속도, 긍정 개수: 8, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 0
# 가게 ID: 209145847, 가게 이름: 바다고기
#   측면: 가성비, 긍정 개수: 7, 부정 개수: 22
#   측면: 청결도, 긍정 개수: 7, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 3
#   측면: 속도, 긍정 개수: 5, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 0
# 가게 ID: 1838844768, 가게 이름: 노상치킨 양재점
#   측면: 가성비, 긍정 개수: 14, 부정 개수: 4
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 2, 부정 개수: 1
#   측면: 속도, 긍정 개수: 0, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 0
# 가게 ID: 1106978299, 가게 이름: 세광양대창 양재점
#   측면: 가성비, 긍정 개수: 142, 부정 개수: 119
#   측면: 청결도, 긍정 개수: 15, 부정 개수: 10
#   측면: 재방문, 긍정 개수: 45, 부정 개수: 8
#   측면: 속도, 긍정 개수: 13, 부정 개수: 16
#   측면: 분위기, 긍정 개수: 48, 부정 개수: 22
# 가게 ID: 18747564, 가게 이름: 소부곱창
#   측면: 가성비, 긍정 개수: 14, 부정 개수: 25
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 0
#   측면: 속도, 긍정 개수: 2, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 4
# 가게 ID: 964119437, 가게 이름: 스시썸
#   측면: 가성비, 긍정 개수: 108, 부정 개수: 64
#   측면: 청결도, 긍정 개수: 16, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 62, 부정 개수: 7
#   측면: 속도, 긍정 개수: 6, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 64, 부정 개수: 20
# 가게 ID: 12981147, 가게 이름: 갈비세상 양재본점
#   측면: 가성비, 긍정 개수: 36, 부정 개수: 60
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 16, 부정 개수: 4
#   측면: 속도, 긍정 개수: 4, 부정 개수: 13
#   측면: 분위기, 긍정 개수: 17, 부정 개수: 14
# 가게 ID: 46696494, 가게 이름: 태국식당356
#   측면: 가성비, 긍정 개수: 70, 부정 개수: 67
#   측면: 청결도, 긍정 개수: 15, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 27, 부정 개수: 5
#   측면: 속도, 긍정 개수: 4, 부정 개수: 10
#   측면: 분위기, 긍정 개수: 12, 부정 개수: 10
# 가게 ID: 38229207, 가게 이름: 만복국수집 양재점
#   측면: 가성비, 긍정 개수: 30, 부정 개수: 25
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 5
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 4
# 가게 ID: 179368379, 가게 이름: 24시찹쌀순대만드는집
#   측면: 가성비, 긍정 개수: 21, 부정 개수: 30
#   측면: 청결도, 긍정 개수: 9, 부정 개수: 14
#   측면: 재방문, 긍정 개수: 1, 부정 개수: 4
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 1
# 가게 ID: 1188227652, 가게 이름: 소곰집 양재점
#   측면: 가성비, 긍정 개수: 102, 부정 개수: 54
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 32, 부정 개수: 10
#   측면: 속도, 긍정 개수: 16, 부정 개수: 18
#   측면: 분위기, 긍정 개수: 11, 부정 개수: 11
# 가게 ID: 32708325, 가게 이름: 강촌원조쭈꾸미본점
#   측면: 가성비, 긍정 개수: 30, 부정 개수: 53
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 12, 부정 개수: 5
#   측면: 속도, 긍정 개수: 4, 부정 개수: 17
#   측면: 분위기, 긍정 개수: 10, 부정 개수: 5
# 가게 ID: 38248908, 가게 이름: 치킨영토 양재점
#   측면: 가성비, 긍정 개수: 2, 부정 개수: 12
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 1, 부정 개수: 0
#   측면: 속도, 긍정 개수: 0, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 2
# 가게 ID: 12962167, 가게 이름: 라그릴리아 양재점
#   측면: 가성비, 긍정 개수: 28, 부정 개수: 40
#   측면: 청결도, 긍정 개수: 11, 부정 개수: 11
#   측면: 재방문, 긍정 개수: 12, 부정 개수: 5
#   측면: 속도, 긍정 개수: 12, 부정 개수: 23
#   측면: 분위기, 긍정 개수: 72, 부정 개수: 49
# 가게 ID: 1735144615, 가게 이름: 이층완우
#   측면: 가성비, 긍정 개수: 43, 부정 개수: 37
#   측면: 청결도, 긍정 개수: 34, 부정 개수: 9
#   측면: 재방문, 긍정 개수: 36, 부정 개수: 4
#   측면: 속도, 긍정 개수: 6, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 46, 부정 개수: 11
# 가게 ID: 193891932, 가게 이름: 화차이
#   측면: 가성비, 긍정 개수: 19, 부정 개수: 43
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 9, 부정 개수: 1
#   측면: 속도, 긍정 개수: 9, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 5
# 가게 ID: 1906380511, 가게 이름: 손수동
#   측면: 가성비, 긍정 개수: 108, 부정 개수: 86
#   측면: 청결도, 긍정 개수: 36, 부정 개수: 12
#   측면: 재방문, 긍정 개수: 70, 부정 개수: 15
#   측면: 속도, 긍정 개수: 15, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 16, 부정 개수: 3
# 가게 ID: 1360440438, 가게 이름: 미몽 양재역점
#   측면: 가성비, 긍정 개수: 29, 부정 개수: 18
#   측면: 청결도, 긍정 개수: 7, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 32, 부정 개수: 6
#   측면: 속도, 긍정 개수: 9, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 9, 부정 개수: 2
# 가게 ID: 74715630, 가게 이름: 배수경양재정육식당 9호점
#   측면: 가성비, 긍정 개수: 23, 부정 개수: 56
#   측면: 청결도, 긍정 개수: 0, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 0
#   측면: 속도, 긍정 개수: 1, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 7
# 가게 ID: 13151847, 가게 이름: 돈오리
#   측면: 가성비, 긍정 개수: 7, 부정 개수: 10
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 2
#   측면: 속도, 긍정 개수: 0, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 1
# 가게 ID: 1660867179, 가게 이름: 진여사댁
#   측면: 가성비, 긍정 개수: 69, 부정 개수: 53
#   측면: 청결도, 긍정 개수: 28, 부정 개수: 17
#   측면: 재방문, 긍정 개수: 50, 부정 개수: 11
#   측면: 속도, 긍정 개수: 23, 부정 개수: 31
#   측면: 분위기, 긍정 개수: 44, 부정 개수: 29
# 가게 ID: 151264987, 가게 이름: 하우림 양재점
#   측면: 가성비, 긍정 개수: 26, 부정 개수: 27
#   측면: 청결도, 긍정 개수: 13, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 2
#   측면: 속도, 긍정 개수: 4, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 2
# 가게 ID: 35136252, 가게 이름: 양재닭집
#   측면: 가성비, 긍정 개수: 67, 부정 개수: 72
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 18
#   측면: 재방문, 긍정 개수: 11, 부정 개수: 4
#   측면: 속도, 긍정 개수: 8, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 6
# 가게 ID: 1257299870, 가게 이름: 곰작골나주곰탕 양재점
#   측면: 가성비, 긍정 개수: 45, 부정 개수: 70
#   측면: 청결도, 긍정 개수: 20, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 11, 부정 개수: 2
#   측면: 속도, 긍정 개수: 1, 부정 개수: 7
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 6
# 가게 ID: 12917286, 가게 이름: 영동족발 본점
#   측면: 가성비, 긍정 개수: 24, 부정 개수: 33
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 9, 부정 개수: 7
#   측면: 속도, 긍정 개수: 4, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 2
# 가게 ID: 573699969, 가게 이름: 오선채
#   측면: 가성비, 긍정 개수: 20, 부정 개수: 33
#   측면: 청결도, 긍정 개수: 11, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 1
#   측면: 속도, 긍정 개수: 4, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 15, 부정 개수: 17
# 가게 ID: 620225564, 가게 이름: 김치뚝딱 양재점
#   측면: 가성비, 긍정 개수: 5, 부정 개수: 12
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 0, 부정 개수: 1
#   측면: 속도, 긍정 개수: 0, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 0
# 가게 ID: 38709080, 가게 이름: 백화네부엌
#   측면: 가성비, 긍정 개수: 67, 부정 개수: 56
#   측면: 청결도, 긍정 개수: 15, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 9
#   측면: 속도, 긍정 개수: 10, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 33, 부정 개수: 35
# 가게 ID: 1419339898, 가게 이름: 미담재 양재역점
#   측면: 가성비, 긍정 개수: 62, 부정 개수: 39
#   측면: 청결도, 긍정 개수: 100, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 82, 부정 개수: 9
#   측면: 속도, 긍정 개수: 8, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 52, 부정 개수: 29
# 가게 ID: 36122875, 가게 이름: 설마중
#   측면: 가성비, 긍정 개수: 91, 부정 개수: 82
#   측면: 청결도, 긍정 개수: 9, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 8
#   측면: 속도, 긍정 개수: 5, 부정 개수: 15
#   측면: 분위기, 긍정 개수: 62, 부정 개수: 49
# 가게 ID: 1090964067, 가게 이름: 인덕원비빔국수 양재직영점
#   측면: 가성비, 긍정 개수: 15, 부정 개수: 30
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 4
#   측면: 속도, 긍정 개수: 10, 부정 개수: 9
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 9
# 가게 ID: 765084210, 가게 이름: 산내골소갈비살
#   측면: 가성비, 긍정 개수: 43, 부정 개수: 26
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 10, 부정 개수: 0
#   측면: 속도, 긍정 개수: 6, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 9, 부정 개수: 0
# 가게 ID: 11680229, 가게 이름: 신선설농탕 도곡점
#   측면: 가성비, 긍정 개수: 21, 부정 개수: 26
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 3
#   측면: 속도, 긍정 개수: 3, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 2
# 가게 ID: 1618656208, 가게 이름: 명품생대구탕
#   측면: 가성비, 긍정 개수: 14, 부정 개수: 11
#   측면: 청결도, 긍정 개수: 10, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 2, 부정 개수: 2
#   측면: 속도, 긍정 개수: 1, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 0
# 가게 ID: 13160546, 가게 이름: 그램
#   측면: 가성비, 긍정 개수: 51, 부정 개수: 27
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 24, 부정 개수: 4
#   측면: 속도, 긍정 개수: 8, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 41, 부정 개수: 20
# 가게 ID: 1429930181, 가게 이름: 소신
#   측면: 가성비, 긍정 개수: 46, 부정 개수: 52
#   측면: 청결도, 긍정 개수: 17, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 37, 부정 개수: 14
#   측면: 속도, 긍정 개수: 19, 부정 개수: 16
#   측면: 분위기, 긍정 개수: 53, 부정 개수: 36
# 가게 ID: 37657812, 가게 이름: 심야식당
#   측면: 가성비, 긍정 개수: 44, 부정 개수: 26
#   측면: 청결도, 긍정 개수: 2, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 3
#   측면: 속도, 긍정 개수: 1, 부정 개수: 7
#   측면: 분위기, 긍정 개수: 21, 부정 개수: 10
# 가게 ID: 34521207, 가게 이름: 청정횟집
#   측면: 가성비, 긍정 개수: 9, 부정 개수: 15
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 1, 부정 개수: 1
#   측면: 속도, 긍정 개수: 0, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 1
# 가게 ID: 13150657, 가게 이름: 양재민물매운탕
#   측면: 가성비, 긍정 개수: 6, 부정 개수: 2
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 6, 부정 개수: 2
#   측면: 속도, 긍정 개수: 3, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 2
# 가게 ID: 13323748, 가게 이름: 박고볼래실내포차
#   측면: 가성비, 긍정 개수: 29, 부정 개수: 24
#   측면: 청결도, 긍정 개수: 0, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 10, 부정 개수: 3
#   측면: 속도, 긍정 개수: 3, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 9, 부정 개수: 6
# 가게 ID: 1173026949, 가게 이름: 영동회관
#   측면: 가성비, 긍정 개수: 79, 부정 개수: 43
#   측면: 청결도, 긍정 개수: 15, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 52, 부정 개수: 6
#   측면: 속도, 긍정 개수: 17, 부정 개수: 15
#   측면: 분위기, 긍정 개수: 13, 부정 개수: 10
# 가게 ID: 1417896057, 가게 이름: 카츠공방 양재점
#   측면: 가성비, 긍정 개수: 11, 부정 개수: 6
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 21, 부정 개수: 4
#   측면: 속도, 긍정 개수: 6, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 1
# 가게 ID: 38251615, 가게 이름: 문어세상해천탕 양재점
#   측면: 가성비, 긍정 개수: 35, 부정 개수: 31
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 0
#   측면: 속도, 긍정 개수: 3, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 8
# 가게 ID: 1123021012, 가게 이름: 호랑이초밥 양재점
#   측면: 가성비, 긍정 개수: 79, 부정 개수: 24
#   측면: 청결도, 긍정 개수: 31, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 44, 부정 개수: 13
#   측면: 속도, 긍정 개수: 4, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 19, 부정 개수: 10
# 가게 ID: 34345158, 가게 이름: 양재정육식당 3호점
#   측면: 가성비, 긍정 개수: 12, 부정 개수: 20
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 2
#   측면: 속도, 긍정 개수: 2, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 2
# 가게 ID: 37889898, 가게 이름: 콩뿌리콩나물국밥 양재점
#   측면: 가성비, 긍정 개수: 16, 부정 개수: 22
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 4
#   측면: 속도, 긍정 개수: 4, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 4
# 가게 ID: 13376678, 가게 이름: 한솥도시락 양재교육개발원입구점
#   측면: 가성비, 긍정 개수: 32, 부정 개수: 12
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 1
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 0
# 가게 ID: 1830398009, 가게 이름: 서리풀돈까스
#   측면: 가성비, 긍정 개수: 21, 부정 개수: 14
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 6
#   측면: 속도, 긍정 개수: 7, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 0
# 가게 ID: 37307613, 가게 이름: 양재오제섞어 양재본점
#   측면: 가성비, 긍정 개수: 51, 부정 개수: 84
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 16, 부정 개수: 11
#   측면: 속도, 긍정 개수: 10, 부정 개수: 13
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 3
# 가게 ID: 1927679596, 가게 이름: 에베레스트 양재점
#   측면: 가성비, 긍정 개수: 71, 부정 개수: 40
#   측면: 청결도, 긍정 개수: 13, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 82, 부정 개수: 11
#   측면: 속도, 긍정 개수: 6, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 23, 부정 개수: 12
# 가게 ID: 1886378828, 가게 이름: 곱창왕김형제 양재역본점
#   측면: 가성비, 긍정 개수: 33, 부정 개수: 48
#   측면: 청결도, 긍정 개수: 9, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 25, 부정 개수: 5
#   측면: 속도, 긍정 개수: 7, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 3
# 가게 ID: 1891561259, 가게 이름: 월계랑
#   측면: 가성비, 긍정 개수: 33, 부정 개수: 10
#   측면: 청결도, 긍정 개수: 14, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 25, 부정 개수: 1
#   측면: 속도, 긍정 개수: 1, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 8, 부정 개수: 2
# 가게 ID: 1278613093, 가게 이름: 지세포세꼬시
#   측면: 가성비, 긍정 개수: 14, 부정 개수: 14
#   측면: 청결도, 긍정 개수: 0, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 6, 부정 개수: 2
#   측면: 속도, 긍정 개수: 2, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 7
# 가게 ID: 13348519, 가게 이름: 타이쇼
#   측면: 가성비, 긍정 개수: 121, 부정 개수: 101
#   측면: 청결도, 긍정 개수: 19, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 111, 부정 개수: 12
#   측면: 속도, 긍정 개수: 22, 부정 개수: 22
#   측면: 분위기, 긍정 개수: 126, 부정 개수: 62
# 가게 ID: 1567180996, 가게 이름: 에그드랍 양재역점
#   측면: 가성비, 긍정 개수: 10, 부정 개수: 4
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 0, 부정 개수: 3
#   측면: 속도, 긍정 개수: 0, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 1
# 가게 ID: 31186755, 가게 이름: 아리노마마
#   측면: 가성비, 긍정 개수: 41, 부정 개수: 46
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 11
#   측면: 재방문, 긍정 개수: 21, 부정 개수: 6
#   측면: 속도, 긍정 개수: 6, 부정 개수: 13
#   측면: 분위기, 긍정 개수: 66, 부정 개수: 30
# 가게 ID: 1807443956, 가게 이름: 양재역 조개맛집
#   측면: 가성비, 긍정 개수: 35, 부정 개수: 29
#   측면: 청결도, 긍정 개수: 2, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 11, 부정 개수: 2
#   측면: 속도, 긍정 개수: 1, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 17, 부정 개수: 11
# 가게 ID: 1944962798, 가게 이름: 이가네양꼬치 양재역직영점
#   측면: 가성비, 긍정 개수: 129, 부정 개수: 186
#   측면: 청결도, 긍정 개수: 22, 부정 개수: 16
#   측면: 재방문, 긍정 개수: 26, 부정 개수: 12
#   측면: 속도, 긍정 개수: 40, 부정 개수: 43
#   측면: 분위기, 긍정 개수: 13, 부정 개수: 8
# 가게 ID: 31600260, 가게 이름: 잰부닥
#   측면: 가성비, 긍정 개수: 39, 부정 개수: 75
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 14, 부정 개수: 10
#   측면: 속도, 긍정 개수: 8, 부정 개수: 16
#   측면: 분위기, 긍정 개수: 10, 부정 개수: 19
# 가게 ID: 234208683, 가게 이름: 양인환대
#   측면: 가성비, 긍정 개수: 104, 부정 개수: 149
#   측면: 청결도, 긍정 개수: 25, 부정 개수: 18
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 12
#   측면: 속도, 긍정 개수: 12, 부정 개수: 21
#   측면: 분위기, 긍정 개수: 55, 부정 개수: 26
# 가게 ID: 38474259, 가게 이름: 오향절면 양재본점
#   측면: 가성비, 긍정 개수: 57, 부정 개수: 39
#   측면: 청결도, 긍정 개수: 21, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 23, 부정 개수: 5
#   측면: 속도, 긍정 개수: 10, 부정 개수: 7
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 9
# 가게 ID: 1672141709, 가게 이름: 육즙관리소 양재역점
#   측면: 가성비, 긍정 개수: 65, 부정 개수: 61
#   측면: 청결도, 긍정 개수: 76, 부정 개수: 50
#   측면: 재방문, 긍정 개수: 93, 부정 개수: 31
#   측면: 속도, 긍정 개수: 16, 부정 개수: 21
#   측면: 분위기, 긍정 개수: 108, 부정 개수: 73
# 가게 ID: 1658172503, 가게 이름: 닭곰탱이 양재역점
#   측면: 가성비, 긍정 개수: 47, 부정 개수: 29
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 1
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 8, 부정 개수: 2
# 가게 ID: 1037966057, 가게 이름: 피끄니크
#   측면: 가성비, 긍정 개수: 84, 부정 개수: 56
#   측면: 청결도, 긍정 개수: 22, 부정 개수: 7
#   측면: 재방문, 긍정 개수: 40, 부정 개수: 18
#   측면: 속도, 긍정 개수: 12, 부정 개수: 10
#   측면: 분위기, 긍정 개수: 28, 부정 개수: 12
# 가게 ID: 1786476142, 가게 이름: 로마옥 도곡
#   측면: 가성비, 긍정 개수: 24, 부정 개수: 44
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 17, 부정 개수: 3
#   측면: 속도, 긍정 개수: 8, 부정 개수: 12
#   측면: 분위기, 긍정 개수: 86, 부정 개수: 50
# 가게 ID: 36538658, 가게 이름: 니혼슈바 슈토
#   측면: 가성비, 긍정 개수: 72, 부정 개수: 50
#   측면: 청결도, 긍정 개수: 7, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 22, 부정 개수: 10
#   측면: 속도, 긍정 개수: 4, 부정 개수: 17
#   측면: 분위기, 긍정 개수: 49, 부정 개수: 32
# 가게 ID: 20897027, 가게 이름: 작은공간
#   측면: 가성비, 긍정 개수: 52, 부정 개수: 50
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 8
#   측면: 속도, 긍정 개수: 20, 부정 개수: 21
#   측면: 분위기, 긍정 개수: 8, 부정 개수: 8
# 가게 ID: 37615410, 가게 이름: 신전떡볶이 도곡점
#   측면: 가성비, 긍정 개수: 12, 부정 개수: 8
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 9, 부정 개수: 1
#   측면: 속도, 긍정 개수: 1, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 1
# 가게 ID: 35155951, 가게 이름: 국미당
#   측면: 가성비, 긍정 개수: 25, 부정 개수: 59
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 12
#   측면: 재방문, 긍정 개수: 9, 부정 개수: 4
#   측면: 속도, 긍정 개수: 4, 부정 개수: 16
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 5
# 가게 ID: 1034622849, 가게 이름: 국고집
#   측면: 가성비, 긍정 개수: 253, 부정 개수: 143
#   측면: 청결도, 긍정 개수: 41, 부정 개수: 20
#   측면: 재방문, 긍정 개수: 77, 부정 개수: 25
#   측면: 속도, 긍정 개수: 18, 부정 개수: 15
#   측면: 분위기, 긍정 개수: 32, 부정 개수: 48
# 가게 ID: 30922907, 가게 이름: 스파게티스토리
#   측면: 가성비, 긍정 개수: 39, 부정 개수: 35
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 1
#   측면: 속도, 긍정 개수: 5, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 1
# 가게 ID: 20601502, 가게 이름: 그린네 은쟁반
#   측면: 가성비, 긍정 개수: 26, 부정 개수: 28
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 6, 부정 개수: 5
#   측면: 속도, 긍정 개수: 2, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 1
# 가게 ID: 1889974700, 가게 이름: 마라홀릭 마라탕 양재역점
#   측면: 가성비, 긍정 개수: 36, 부정 개수: 22
#   측면: 청결도, 긍정 개수: 16, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 52, 부정 개수: 2
#   측면: 속도, 긍정 개수: 8, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 2
# 가게 ID: 1672897084, 가게 이름: 본죽&비빔밥cafe 양재은광여고점
#   측면: 가성비, 긍정 개수: 22, 부정 개수: 15
#   측면: 청결도, 긍정 개수: 18, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 11, 부정 개수: 4
#   측면: 속도, 긍정 개수: 11, 부정 개수: 14
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 1
# 가게 ID: 35307516, 가게 이름: 제레미버거
#   측면: 가성비, 긍정 개수: 34, 부정 개수: 38
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 10, 부정 개수: 6
#   측면: 속도, 긍정 개수: 10, 부정 개수: 12
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 3
# 가게 ID: 34098856, 가게 이름: 얌얌 양재점
#   측면: 가성비, 긍정 개수: 21, 부정 개수: 16
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 15, 부정 개수: 3
#   측면: 속도, 긍정 개수: 12, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 1
# 가게 ID: 12950069, 가게 이름: 디오디아2.0
#   측면: 가성비, 긍정 개수: 186, 부정 개수: 143
#   측면: 청결도, 긍정 개수: 39, 부정 개수: 14
#   측면: 재방문, 긍정 개수: 79, 부정 개수: 21
#   측면: 속도, 긍정 개수: 44, 부정 개수: 52
#   측면: 분위기, 긍정 개수: 121, 부정 개수: 75
# 가게 ID: 1664070278, 가게 이름: 용짜장 양재점
#   측면: 가성비, 긍정 개수: 15, 부정 개수: 13
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 2, 부정 개수: 0
#   측면: 속도, 긍정 개수: 1, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 0
# 가게 ID: 1154400830, 가게 이름: 깐부치킨 양재역점
#   측면: 가성비, 긍정 개수: 16, 부정 개수: 26
#   측면: 청결도, 긍정 개수: 0, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 3
#   측면: 속도, 긍정 개수: 3, 부정 개수: 7
#   측면: 분위기, 긍정 개수: 8, 부정 개수: 2
# 가게 ID: 33459979, 가게 이름: 치킨처럼 양재역점
#   측면: 가성비, 긍정 개수: 30, 부정 개수: 26
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 1, 부정 개수: 2
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 4
# 가게 ID: 32699962, 가게 이름: 장수정육식당
#   측면: 가성비, 긍정 개수: 13, 부정 개수: 5
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 1, 부정 개수: 0
#   측면: 속도, 긍정 개수: 2, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 0
# 가게 ID: 1069491314, 가게 이름: 뎁짜이 양재역점
#   측면: 가성비, 긍정 개수: 37, 부정 개수: 18
#   측면: 청결도, 긍정 개수: 20, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 32, 부정 개수: 8
#   측면: 속도, 긍정 개수: 8, 부정 개수: 9
#   측면: 분위기, 긍정 개수: 11, 부정 개수: 4
# 가게 ID: 19882315, 가게 이름: 자인뭉티기
#   측면: 가성비, 긍정 개수: 29, 부정 개수: 43
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 19, 부정 개수: 0
#   측면: 속도, 긍정 개수: 11, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 12, 부정 개수: 12
# 가게 ID: 1081786133, 가게 이름: 훅트포케 양재점
#   측면: 가성비, 긍정 개수: 59, 부정 개수: 40
#   측면: 청결도, 긍정 개수: 28, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 41, 부정 개수: 5
#   측면: 속도, 긍정 개수: 3, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 22, 부정 개수: 3
# 가게 ID: 1625687301, 가게 이름: 힐튼가든인 서울강남 가든 비스트로
#   측면: 가성비, 긍정 개수: 128, 부정 개수: 105
#   측면: 청결도, 긍정 개수: 43, 부정 개수: 10
#   측면: 재방문, 긍정 개수: 46, 부정 개수: 29
#   측면: 속도, 긍정 개수: 12, 부정 개수: 27
#   측면: 분위기, 긍정 개수: 91, 부정 개수: 53
# 가게 ID: 38643869, 가게 이름: 양지수제샌드위치
#   측면: 가성비, 긍정 개수: 9, 부정 개수: 27
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 5
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 7, 부정 개수: 1
# 가게 ID: 36868411, 가게 이름: 순남시래기 양재점
#   측면: 가성비, 긍정 개수: 53, 부정 개수: 38
#   측면: 청결도, 긍정 개수: 10, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 13, 부정 개수: 6
#   측면: 속도, 긍정 개수: 13, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 3
# 가게 ID: 20874669, 가게 이름: 황재벌 본점
#   측면: 가성비, 긍정 개수: 86, 부정 개수: 110
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 11
#   측면: 재방문, 긍정 개수: 17, 부정 개수: 6
#   측면: 속도, 긍정 개수: 36, 부정 개수: 41
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 8
# 가게 ID: 13157782, 가게 이름: 늘봄족발보쌈
#   측면: 가성비, 긍정 개수: 22, 부정 개수: 4
#   측면: 청결도, 긍정 개수: 2, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 3
#   측면: 속도, 긍정 개수: 1, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 3
# 가게 ID: 1192671730, 가게 이름: 오부찌 양재점
#   측면: 가성비, 긍정 개수: 67, 부정 개수: 41
#   측면: 청결도, 긍정 개수: 15, 부정 개수: 7
#   측면: 재방문, 긍정 개수: 19, 부정 개수: 8
#   측면: 속도, 긍정 개수: 13, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 2
# 가게 ID: 38591616, 가게 이름: 고양이부엌 양재구청점
#   측면: 가성비, 긍정 개수: 65, 부정 개수: 40
#   측면: 청결도, 긍정 개수: 5, 부정 개수: 7
#   측면: 재방문, 긍정 개수: 6, 부정 개수: 8
#   측면: 속도, 긍정 개수: 3, 부정 개수: 8
#   측면: 분위기, 긍정 개수: 12, 부정 개수: 1
# 가게 ID: 1320179295, 가게 이름: 크라이치즈버거 양재역점
#   측면: 가성비, 긍정 개수: 16, 부정 개수: 33
#   측면: 청결도, 긍정 개수: 11, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 5
#   측면: 속도, 긍정 개수: 0, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 1
# 가게 ID: 11861500, 가게 이름: 전주옛날집
#   측면: 가성비, 긍정 개수: 17, 부정 개수: 14
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 1, 부정 개수: 3
#   측면: 속도, 긍정 개수: 3, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 9
# 가게 ID: 1078767514, 가게 이름: 서초목살
#   측면: 가성비, 긍정 개수: 24, 부정 개수: 12
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 0
#   측면: 재방문, 긍정 개수: 44, 부정 개수: 1
#   측면: 속도, 긍정 개수: 6, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 5, 부정 개수: 7
# 가게 ID: 31134978, 가게 이름: 본도시락 양재점
#   측면: 가성비, 긍정 개수: 13, 부정 개수: 8
#   측면: 청결도, 긍정 개수: 3, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 0
#   측면: 속도, 긍정 개수: 5, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 1
# 가게 ID: 18771333, 가게 이름: 진스시
#   측면: 가성비, 긍정 개수: 91, 부정 개수: 78
#   측면: 청결도, 긍정 개수: 45, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 23, 부정 개수: 12
#   측면: 속도, 긍정 개수: 14, 부정 개수: 19
#   측면: 분위기, 긍정 개수: 81, 부정 개수: 42
# 가게 ID: 37997726, 가게 이름: 봉피양 양재점
#   측면: 가성비, 긍정 개수: 105, 부정 개수: 140
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 12
#   측면: 재방문, 긍정 개수: 3, 부정 개수: 5
#   측면: 속도, 긍정 개수: 8, 부정 개수: 29
#   측면: 분위기, 긍정 개수: 20, 부정 개수: 20
# 가게 ID: 37236849, 가게 이름: 돼지연구소 양재직영점
#   측면: 가성비, 긍정 개수: 16, 부정 개수: 27
#   측면: 청결도, 긍정 개수: 7, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 27, 부정 개수: 7
#   측면: 속도, 긍정 개수: 11, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 5
# 가게 ID: 1268565080, 가게 이름: 솥두껍 양재본점
#   측면: 가성비, 긍정 개수: 260, 부정 개수: 198
#   측면: 청결도, 긍정 개수: 21, 부정 개수: 11
#   측면: 재방문, 긍정 개수: 104, 부정 개수: 24
#   측면: 속도, 긍정 개수: 17, 부정 개수: 23
#   측면: 분위기, 긍정 개수: 15, 부정 개수: 14
# 가게 ID: 37902481, 가게 이름: 깡돈
#   측면: 가성비, 긍정 개수: 28, 부정 개수: 13
#   측면: 청결도, 긍정 개수: 0, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 0
#   측면: 속도, 긍정 개수: 3, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 0
# 가게 ID: 32821881, 가게 이름: 토봉추어탕
#   측면: 가성비, 긍정 개수: 28, 부정 개수: 29
#   측면: 청결도, 긍정 개수: 14, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 6
#   측면: 속도, 긍정 개수: 6, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 0
# 가게 ID: 1044461398, 가게 이름: 우대포 양재점
#   측면: 가성비, 긍정 개수: 213, 부정 개수: 106
#   측면: 청결도, 긍정 개수: 55, 부정 개수: 10
#   측면: 재방문, 긍정 개수: 94, 부정 개수: 16
#   측면: 속도, 긍정 개수: 24, 부정 개수: 20
#   측면: 분위기, 긍정 개수: 24, 부정 개수: 13
# 가게 ID: 11627634, 가게 이름: 버드나무집 서초동본점
#   측면: 가성비, 긍정 개수: 36, 부정 개수: 61
#   측면: 청결도, 긍정 개수: 7, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 5
#   측면: 속도, 긍정 개수: 3, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 11
# 가게 ID: 18779141, 가게 이름: 듬북담북 뱅뱅점
#   측면: 가성비, 긍정 개수: 12, 부정 개수: 8
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 2
#   측면: 속도, 긍정 개수: 1, 부정 개수: 0
#   측면: 분위기, 긍정 개수: 2, 부정 개수: 6
# 가게 ID: 98898756, 가게 이름: 양재정육식당 역삼뱅뱅점
#   측면: 가성비, 긍정 개수: 64, 부정 개수: 51
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 11, 부정 개수: 2
#   측면: 속도, 긍정 개수: 3, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 6
# 가게 ID: 13150366, 가게 이름: 참설농탕 서초점
#   측면: 가성비, 긍정 개수: 17, 부정 개수: 63
#   측면: 청결도, 긍정 개수: 9, 부정 개수: 11
#   측면: 재방문, 긍정 개수: 20, 부정 개수: 10
#   측면: 속도, 긍정 개수: 9, 부정 개수: 9
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 2
# 가게 ID: 1550997885, 가게 이름: 부안애서 서초점
#   측면: 가성비, 긍정 개수: 97, 부정 개수: 50
#   측면: 청결도, 긍정 개수: 53, 부정 개수: 8
#   측면: 재방문, 긍정 개수: 55, 부정 개수: 17
#   측면: 속도, 긍정 개수: 14, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 41, 부정 개수: 22
# 가게 ID: 34582729, 가게 이름: 담소소사골순대육개장 서초점
#   측면: 가성비, 긍정 개수: 25, 부정 개수: 12
#   측면: 청결도, 긍정 개수: 8, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 5, 부정 개수: 4
#   측면: 속도, 긍정 개수: 2, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 1
# 가게 ID: 18361460, 가게 이름: 광양참숯불고기
#   측면: 가성비, 긍정 개수: 28, 부정 개수: 40
#   측면: 청결도, 긍정 개수: 13, 부정 개수: 6
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 4
#   측면: 속도, 긍정 개수: 1, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 7
# 가게 ID: 1532111915, 가게 이름: 푸라닭 서초2동점
#   측면: 가성비, 긍정 개수: 9, 부정 개수: 9
#   측면: 청결도, 긍정 개수: 7, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 2
#   측면: 속도, 긍정 개수: 5, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 6
# 가게 ID: 1925656389, 가게 이름: 피넘타이
#   측면: 가성비, 긍정 개수: 38, 부정 개수: 27
#   측면: 청결도, 긍정 개수: 16, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 24, 부정 개수: 3
#   측면: 속도, 긍정 개수: 6, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 19, 부정 개수: 2
# 가게 ID: 20083769, 가게 이름: 전사랑 서초본점
#   측면: 가성비, 긍정 개수: 73, 부정 개수: 59
#   측면: 청결도, 긍정 개수: 16, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 25, 부정 개수: 4
#   측면: 속도, 긍정 개수: 6, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 14, 부정 개수: 7
# 가게 ID: 1137666363, 가게 이름: 옥된장 양재점
#   측면: 가성비, 긍정 개수: 29, 부정 개수: 16
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 13, 부정 개수: 2
#   측면: 속도, 긍정 개수: 3, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 11, 부정 개수: 3
# 가게 ID: 1553486347, 가게 이름: 마라두목 양재점
#   측면: 가성비, 긍정 개수: 30, 부정 개수: 14
#   측면: 청결도, 긍정 개수: 32, 부정 개수: 7
#   측면: 재방문, 긍정 개수: 24, 부정 개수: 3
#   측면: 속도, 긍정 개수: 9, 부정 개수: 3
#   측면: 분위기, 긍정 개수: 14, 부정 개수: 1
# 가게 ID: 1688755338, 가게 이름: 백소정 양재역점
#   측면: 가성비, 긍정 개수: 64, 부정 개수: 16
#   측면: 청결도, 긍정 개수: 50, 부정 개수: 9
#   측면: 재방문, 긍정 개수: 40, 부정 개수: 5
#   측면: 속도, 긍정 개수: 13, 부정 개수: 15
#   측면: 분위기, 긍정 개수: 8, 부정 개수: 3
# 가게 ID: 1516711006, 가게 이름: 불로삼계백숙
#   측면: 가성비, 긍정 개수: 53, 부정 개수: 35
#   측면: 청결도, 긍정 개수: 9, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 14, 부정 개수: 7
#   측면: 속도, 긍정 개수: 3, 부정 개수: 5
#   측면: 분위기, 긍정 개수: 7, 부정 개수: 3
# 가게 ID: 1932467805, 가게 이름: 보글이 생태탕왕코다리 양재역점
#   측면: 가성비, 긍정 개수: 182, 부정 개수: 82
#   측면: 청결도, 긍정 개수: 25, 부정 개수: 2
#   측면: 재방문, 긍정 개수: 40, 부정 개수: 12
#   측면: 속도, 긍정 개수: 11, 부정 개수: 12
#   측면: 분위기, 긍정 개수: 15, 부정 개수: 8
# 가게 ID: 1698302178, 가게 이름: 도화
#   측면: 가성비, 긍정 개수: 48, 부정 개수: 31
#   측면: 청결도, 긍정 개수: 17, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 4
#   측면: 속도, 긍정 개수: 5, 부정 개수: 7
#   측면: 분위기, 긍정 개수: 15, 부정 개수: 6
# 가게 ID: 1751873950, 가게 이름: 양재순대
#   측면: 가성비, 긍정 개수: 49, 부정 개수: 46
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 13
#   측면: 재방문, 긍정 개수: 8, 부정 개수: 7
#   측면: 속도, 긍정 개수: 18, 부정 개수: 21
#   측면: 분위기, 긍정 개수: 6, 부정 개수: 3
# 가게 ID: 18307489, 가게 이름: 어부참치
#   측면: 가성비, 긍정 개수: 5, 부정 개수: 14
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 4, 부정 개수: 1
#   측면: 속도, 긍정 개수: 1, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 1, 부정 개수: 0
# 가게 ID: 1941253545, 가게 이름: Poke all day 포케&샐러드 양재점
#   측면: 가성비, 긍정 개수: 77, 부정 개수: 70
#   측면: 청결도, 긍정 개수: 56, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 48, 부정 개수: 10
#   측면: 속도, 긍정 개수: 9, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 18, 부정 개수: 6
# 가게 ID: 1827894067, 가게 이름: 명가무안뻘낙지
#   측면: 가성비, 긍정 개수: 7, 부정 개수: 24
#   측면: 청결도, 긍정 개수: 1, 부정 개수: 9
#   측면: 재방문, 긍정 개수: 6, 부정 개수: 2
#   측면: 속도, 긍정 개수: 0, 부정 개수: 4
#   측면: 분위기, 긍정 개수: 3, 부정 개수: 2
# 가게 ID: 13150440, 가게 이름: 콩나루콩나물국밥 직영점
#   측면: 가성비, 긍정 개수: 10, 부정 개수: 7
#   측면: 청결도, 긍정 개수: 0, 부정 개수: 1
#   측면: 재방문, 긍정 개수: 7, 부정 개수: 2
#   측면: 속도, 긍정 개수: 3, 부정 개수: 2
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 0
# 가게 ID: 1361137881, 가게 이름: 채석강
#   측면: 가성비, 긍정 개수: 42, 부정 개수: 43
#   측면: 청결도, 긍정 개수: 16, 부정 개수: 4
#   측면: 재방문, 긍정 개수: 9, 부정 개수: 3
#   측면: 속도, 긍정 개수: 3, 부정 개수: 6
#   측면: 분위기, 긍정 개수: 4, 부정 개수: 0
# 가게 ID: 1420055829, 가게 이름: 임병주산동칼국수
#   측면: 가성비, 긍정 개수: 38, 부정 개수: 89
#   측면: 청결도, 긍정 개수: 13, 부정 개수: 13
#   측면: 재방문, 긍정 개수: 18, 부정 개수: 18
#   측면: 속도, 긍정 개수: 40, 부정 개수: 41
#   측면: 분위기, 긍정 개수: 11, 부정 개수: 13
# 가게 ID: 1931613846, 가게 이름: 우나유 나고야식 장어덮밥
#   측면: 가성비, 긍정 개수: 41, 부정 개수: 52
#   측면: 청결도, 긍정 개수: 14, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 29, 부정 개수: 5
#   측면: 속도, 긍정 개수: 9, 부정 개수: 11
#   측면: 분위기, 긍정 개수: 25, 부정 개수: 12
# 가게 ID: 36200001, 가게 이름: 춘향골남원추어탕 서초점
#   측면: 가성비, 긍정 개수: 10, 부정 개수: 9
#   측면: 청결도, 긍정 개수: 4, 부정 개수: 3
#   측면: 재방문, 긍정 개수: 2, 부정 개수: 0
#   측면: 속도, 긍정 개수: 1, 부정 개수: 1
#   측면: 분위기, 긍정 개수: 0, 부정 개수: 0
# 가게 ID: 13150444, 가게 이름: 난랑
#   측면: 가성비, 긍정 개수: 42, 부정 개수: 52
#   측면: 청결도, 긍정 개수: 12, 부정 개수: 5
#   측면: 재방문, 긍정 개수: 19, 부정 개수: 4
#   측면: 속도, 긍정 개수: 12, 부정 개수: 9
#   측면: 분위기, 긍정 개수: 25, 부정 개수: 18

# %%
store_aspect_sentiments
# Out:
# {'1582818366': {'store_name': '퀸즈가든 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 172, 'negative': 116},
#    '청결도': {'positive': 31, 'negative': 8},
#    '재방문': {'positive': 35, 'negative': 8},
#    '속도': {'positive': 6, 'negative': 10},
#    '분위기': {'positive': 17, 'negative': 17}}},
#  '37233088': {'store_name': '갈비사랑 양재본점',
#   'aspect_sentiments': {'가성비': {'positive': 22, 'negative': 47},
#    '청결도': {'positive': 12, 'negative': 1},
#    '재방문': {'positive': 18, 'negative': 10},
#    '속도': {'positive': 2, 'negative': 8},
#    '분위기': {'positive': 29, 'negative': 18}}},
#  '38264349': {'store_name': '한양돈까스',
#   'aspect_sentiments': {'가성비': {'positive': 55, 'negative': 73},
#    '청결도': {'positive': 6, 'negative': 9},
#    '재방문': {'positive': 9, 'negative': 9},
#    '속도': {'positive': 11, 'negative': 19},
#    '분위기': {'positive': 4, 'negative': 4}}},
#  '1113983640': {'store_name': '탐라순대국감자탕 양재역직영점',
#   'aspect_sentiments': {'가성비': {'positive': 85, 'negative': 59},
#    '청결도': {'positive': 67, 'negative': 15},
#    '재방문': {'positive': 65, 'negative': 10},
#    '속도': {'positive': 4, 'negative': 3},
#    '분위기': {'positive': 15, 'negative': 9}}},
#  '32254662': {'store_name': '한국순대 본점',
#   'aspect_sentiments': {'가성비': {'positive': 42, 'negative': 72},
#    '청결도': {'positive': 8, 'negative': 7},
#    '재방문': {'positive': 10, 'negative': 2},
#    '속도': {'positive': 11, 'negative': 17},
#    '분위기': {'positive': 6, 'negative': 1}}},
#  '1427943416': {'store_name': '고려향',
#   'aspect_sentiments': {'가성비': {'positive': 6, 'negative': 20},
#    '청결도': {'positive': 5, 'negative': 0},
#    '재방문': {'positive': 8, 'negative': 3},
#    '속도': {'positive': 5, 'negative': 3},
#    '분위기': {'positive': 5, 'negative': 7}}},
#  '1879800911': {'store_name': '쿠니라멘',
#   'aspect_sentiments': {'가성비': {'positive': 17, 'negative': 17},
#    '청결도': {'positive': 5, 'negative': 5},
#    '재방문': {'positive': 7, 'negative': 2},
#    '속도': {'positive': 8, 'negative': 5},
#    '분위기': {'positive': 2, 'negative': 0}}},
#  '209145847': {'store_name': '바다고기',
#   'aspect_sentiments': {'가성비': {'positive': 7, 'negative': 22},
#    '청결도': {'positive': 7, 'negative': 1},
#    '재방문': {'positive': 3, 'negative': 3},
#    '속도': {'positive': 5, 'negative': 4},
#    '분위기': {'positive': 3, 'negative': 0}}},
#  '1838844768': {'store_name': '노상치킨 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 14, 'negative': 4},
#    '청결도': {'positive': 3, 'negative': 5},
#    '재방문': {'positive': 2, 'negative': 1},
#    '속도': {'positive': 0, 'negative': 1},
#    '분위기': {'positive': 2, 'negative': 0}}},
#  '1106978299': {'store_name': '세광양대창 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 142, 'negative': 119},
#    '청결도': {'positive': 15, 'negative': 10},
#    '재방문': {'positive': 45, 'negative': 8},
#    '속도': {'positive': 13, 'negative': 16},
#    '분위기': {'positive': 48, 'negative': 22}}},
#  '18747564': {'store_name': '소부곱창',
#   'aspect_sentiments': {'가성비': {'positive': 14, 'negative': 25},
#    '청결도': {'positive': 1, 'negative': 3},
#    '재방문': {'positive': 4, 'negative': 0},
#    '속도': {'positive': 2, 'negative': 3},
#    '분위기': {'positive': 1, 'negative': 4}}},
#  '964119437': {'store_name': '스시썸',
#   'aspect_sentiments': {'가성비': {'positive': 108, 'negative': 64},
#    '청결도': {'positive': 16, 'negative': 1},
#    '재방문': {'positive': 62, 'negative': 7},
#    '속도': {'positive': 6, 'negative': 3},
#    '분위기': {'positive': 64, 'negative': 20}}},
#  '12981147': {'store_name': '갈비세상 양재본점',
#   'aspect_sentiments': {'가성비': {'positive': 36, 'negative': 60},
#    '청결도': {'positive': 12, 'negative': 4},
#    '재방문': {'positive': 16, 'negative': 4},
#    '속도': {'positive': 4, 'negative': 13},
#    '분위기': {'positive': 17, 'negative': 14}}},
#  '46696494': {'store_name': '태국식당356',
#   'aspect_sentiments': {'가성비': {'positive': 70, 'negative': 67},
#    '청결도': {'positive': 15, 'negative': 5},
#    '재방문': {'positive': 27, 'negative': 5},
#    '속도': {'positive': 4, 'negative': 10},
#    '분위기': {'positive': 12, 'negative': 10}}},
#  '38229207': {'store_name': '만복국수집 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 30, 'negative': 25},
#    '청결도': {'positive': 4, 'negative': 4},
#    '재방문': {'positive': 8, 'negative': 5},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 3, 'negative': 4}}},
#  '179368379': {'store_name': '24시찹쌀순대만드는집',
#   'aspect_sentiments': {'가성비': {'positive': 21, 'negative': 30},
#    '청결도': {'positive': 9, 'negative': 14},
#    '재방문': {'positive': 1, 'negative': 4},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 2, 'negative': 1}}},
#  '1188227652': {'store_name': '소곰집 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 102, 'negative': 54},
#    '청결도': {'positive': 8, 'negative': 6},
#    '재방문': {'positive': 32, 'negative': 10},
#    '속도': {'positive': 16, 'negative': 18},
#    '분위기': {'positive': 11, 'negative': 11}}},
#  '32708325': {'store_name': '강촌원조쭈꾸미본점',
#   'aspect_sentiments': {'가성비': {'positive': 30, 'negative': 53},
#    '청결도': {'positive': 3, 'negative': 6},
#    '재방문': {'positive': 12, 'negative': 5},
#    '속도': {'positive': 4, 'negative': 17},
#    '분위기': {'positive': 10, 'negative': 5}}},
#  '38248908': {'store_name': '치킨영토 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 2, 'negative': 12},
#    '청결도': {'positive': 1, 'negative': 0},
#    '재방문': {'positive': 1, 'negative': 0},
#    '속도': {'positive': 0, 'negative': 2},
#    '분위기': {'positive': 3, 'negative': 2}}},
#  '12962167': {'store_name': '라그릴리아 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 28, 'negative': 40},
#    '청결도': {'positive': 11, 'negative': 11},
#    '재방문': {'positive': 12, 'negative': 5},
#    '속도': {'positive': 12, 'negative': 23},
#    '분위기': {'positive': 72, 'negative': 49}}},
#  '1735144615': {'store_name': '이층완우',
#   'aspect_sentiments': {'가성비': {'positive': 43, 'negative': 37},
#    '청결도': {'positive': 34, 'negative': 9},
#    '재방문': {'positive': 36, 'negative': 4},
#    '속도': {'positive': 6, 'negative': 8},
#    '분위기': {'positive': 46, 'negative': 11}}},
#  '193891932': {'store_name': '화차이',
#   'aspect_sentiments': {'가성비': {'positive': 19, 'negative': 43},
#    '청결도': {'positive': 5, 'negative': 6},
#    '재방문': {'positive': 9, 'negative': 1},
#    '속도': {'positive': 9, 'negative': 1},
#    '분위기': {'positive': 2, 'negative': 5}}},
#  '1906380511': {'store_name': '손수동',
#   'aspect_sentiments': {'가성비': {'positive': 108, 'negative': 86},
#    '청결도': {'positive': 36, 'negative': 12},
#    '재방문': {'positive': 70, 'negative': 15},
#    '속도': {'positive': 15, 'negative': 8},
#    '분위기': {'positive': 16, 'negative': 3}}},
#  '1360440438': {'store_name': '미몽 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 29, 'negative': 18},
#    '청결도': {'positive': 7, 'negative': 2},
#    '재방문': {'positive': 32, 'negative': 6},
#    '속도': {'positive': 9, 'negative': 2},
#    '분위기': {'positive': 9, 'negative': 2}}},
#  '74715630': {'store_name': '배수경양재정육식당 9호점',
#   'aspect_sentiments': {'가성비': {'positive': 23, 'negative': 56},
#    '청결도': {'positive': 0, 'negative': 3},
#    '재방문': {'positive': 4, 'negative': 0},
#    '속도': {'positive': 1, 'negative': 5},
#    '분위기': {'positive': 5, 'negative': 7}}},
#  '13151847': {'store_name': '돈오리',
#   'aspect_sentiments': {'가성비': {'positive': 7, 'negative': 10},
#    '청결도': {'positive': 3, 'negative': 1},
#    '재방문': {'positive': 5, 'negative': 2},
#    '속도': {'positive': 0, 'negative': 0},
#    '분위기': {'positive': 3, 'negative': 1}}},
#  '1660867179': {'store_name': '진여사댁',
#   'aspect_sentiments': {'가성비': {'positive': 69, 'negative': 53},
#    '청결도': {'positive': 28, 'negative': 17},
#    '재방문': {'positive': 50, 'negative': 11},
#    '속도': {'positive': 23, 'negative': 31},
#    '분위기': {'positive': 44, 'negative': 29}}},
#  '151264987': {'store_name': '하우림 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 26, 'negative': 27},
#    '청결도': {'positive': 13, 'negative': 4},
#    '재방문': {'positive': 3, 'negative': 2},
#    '속도': {'positive': 4, 'negative': 5},
#    '분위기': {'positive': 2, 'negative': 2}}},
#  '35136252': {'store_name': '양재닭집',
#   'aspect_sentiments': {'가성비': {'positive': 67, 'negative': 72},
#    '청결도': {'positive': 12, 'negative': 18},
#    '재방문': {'positive': 11, 'negative': 4},
#    '속도': {'positive': 8, 'negative': 11},
#    '분위기': {'positive': 6, 'negative': 6}}},
#  '1257299870': {'store_name': '곰작골나주곰탕 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 45, 'negative': 70},
#    '청결도': {'positive': 20, 'negative': 4},
#    '재방문': {'positive': 11, 'negative': 2},
#    '속도': {'positive': 1, 'negative': 7},
#    '분위기': {'positive': 6, 'negative': 6}}},
#  '12917286': {'store_name': '영동족발 본점',
#   'aspect_sentiments': {'가성비': {'positive': 24, 'negative': 33},
#    '청결도': {'positive': 4, 'negative': 8},
#    '재방문': {'positive': 9, 'negative': 7},
#    '속도': {'positive': 4, 'negative': 11},
#    '분위기': {'positive': 3, 'negative': 2}}},
#  '573699969': {'store_name': '오선채',
#   'aspect_sentiments': {'가성비': {'positive': 20, 'negative': 33},
#    '청결도': {'positive': 11, 'negative': 1},
#    '재방문': {'positive': 8, 'negative': 1},
#    '속도': {'positive': 4, 'negative': 4},
#    '분위기': {'positive': 15, 'negative': 17}}},
#  '620225564': {'store_name': '김치뚝딱 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 5, 'negative': 12},
#    '청결도': {'positive': 3, 'negative': 1},
#    '재방문': {'positive': 0, 'negative': 1},
#    '속도': {'positive': 0, 'negative': 0},
#    '분위기': {'positive': 1, 'negative': 0}}},
#  '38709080': {'store_name': '백화네부엌',
#   'aspect_sentiments': {'가성비': {'positive': 67, 'negative': 56},
#    '청결도': {'positive': 15, 'negative': 5},
#    '재방문': {'positive': 18, 'negative': 9},
#    '속도': {'positive': 10, 'negative': 11},
#    '분위기': {'positive': 33, 'negative': 35}}},
#  '1419339898': {'store_name': '미담재 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 62, 'negative': 39},
#    '청결도': {'positive': 100, 'negative': 5},
#    '재방문': {'positive': 82, 'negative': 9},
#    '속도': {'positive': 8, 'negative': 5},
#    '분위기': {'positive': 52, 'negative': 29}}},
#  '36122875': {'store_name': '설마중',
#   'aspect_sentiments': {'가성비': {'positive': 91, 'negative': 82},
#    '청결도': {'positive': 9, 'negative': 4},
#    '재방문': {'positive': 18, 'negative': 8},
#    '속도': {'positive': 5, 'negative': 15},
#    '분위기': {'positive': 62, 'negative': 49}}},
#  '1090964067': {'store_name': '인덕원비빔국수 양재직영점',
#   'aspect_sentiments': {'가성비': {'positive': 15, 'negative': 30},
#    '청결도': {'positive': 1, 'negative': 4},
#    '재방문': {'positive': 3, 'negative': 4},
#    '속도': {'positive': 10, 'negative': 9},
#    '분위기': {'positive': 5, 'negative': 9}}},
#  '765084210': {'store_name': '산내골소갈비살',
#   'aspect_sentiments': {'가성비': {'positive': 43, 'negative': 26},
#    '청결도': {'positive': 3, 'negative': 1},
#    '재방문': {'positive': 10, 'negative': 0},
#    '속도': {'positive': 6, 'negative': 5},
#    '분위기': {'positive': 9, 'negative': 0}}},
#  '11680229': {'store_name': '신선설농탕 도곡점',
#   'aspect_sentiments': {'가성비': {'positive': 21, 'negative': 26},
#    '청결도': {'positive': 5, 'negative': 2},
#    '재방문': {'positive': 8, 'negative': 3},
#    '속도': {'positive': 3, 'negative': 4},
#    '분위기': {'positive': 1, 'negative': 2}}},
#  '1618656208': {'store_name': '명품생대구탕',
#   'aspect_sentiments': {'가성비': {'positive': 14, 'negative': 11},
#    '청결도': {'positive': 10, 'negative': 1},
#    '재방문': {'positive': 2, 'negative': 2},
#    '속도': {'positive': 1, 'negative': 0},
#    '분위기': {'positive': 4, 'negative': 0}}},
#  '13160546': {'store_name': '그램',
#   'aspect_sentiments': {'가성비': {'positive': 51, 'negative': 27},
#    '청결도': {'positive': 3, 'negative': 6},
#    '재방문': {'positive': 24, 'negative': 4},
#    '속도': {'positive': 8, 'negative': 5},
#    '분위기': {'positive': 41, 'negative': 20}}},
#  '1429930181': {'store_name': '소신',
#   'aspect_sentiments': {'가성비': {'positive': 46, 'negative': 52},
#    '청결도': {'positive': 17, 'negative': 6},
#    '재방문': {'positive': 37, 'negative': 14},
#    '속도': {'positive': 19, 'negative': 16},
#    '분위기': {'positive': 53, 'negative': 36}}},
#  '37657812': {'store_name': '심야식당',
#   'aspect_sentiments': {'가성비': {'positive': 44, 'negative': 26},
#    '청결도': {'positive': 2, 'negative': 8},
#    '재방문': {'positive': 4, 'negative': 3},
#    '속도': {'positive': 1, 'negative': 7},
#    '분위기': {'positive': 21, 'negative': 10}}},
#  '34521207': {'store_name': '청정횟집',
#   'aspect_sentiments': {'가성비': {'positive': 9, 'negative': 15},
#    '청결도': {'positive': 3, 'negative': 0},
#    '재방문': {'positive': 1, 'negative': 1},
#    '속도': {'positive': 0, 'negative': 1},
#    '분위기': {'positive': 0, 'negative': 1}}},
#  '13150657': {'store_name': '양재민물매운탕',
#   'aspect_sentiments': {'가성비': {'positive': 6, 'negative': 2},
#    '청결도': {'positive': 1, 'negative': 3},
#    '재방문': {'positive': 6, 'negative': 2},
#    '속도': {'positive': 3, 'negative': 5},
#    '분위기': {'positive': 2, 'negative': 2}}},
#  '13323748': {'store_name': '박고볼래실내포차',
#   'aspect_sentiments': {'가성비': {'positive': 29, 'negative': 24},
#    '청결도': {'positive': 0, 'negative': 2},
#    '재방문': {'positive': 10, 'negative': 3},
#    '속도': {'positive': 3, 'negative': 4},
#    '분위기': {'positive': 9, 'negative': 6}}},
#  '1173026949': {'store_name': '영동회관',
#   'aspect_sentiments': {'가성비': {'positive': 79, 'negative': 43},
#    '청결도': {'positive': 15, 'negative': 5},
#    '재방문': {'positive': 52, 'negative': 6},
#    '속도': {'positive': 17, 'negative': 15},
#    '분위기': {'positive': 13, 'negative': 10}}},
#  '1417896057': {'store_name': '카츠공방 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 11, 'negative': 6},
#    '청결도': {'positive': 8, 'negative': 1},
#    '재방문': {'positive': 21, 'negative': 4},
#    '속도': {'positive': 6, 'negative': 4},
#    '분위기': {'positive': 4, 'negative': 1}}},
#  '38251615': {'store_name': '문어세상해천탕 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 35, 'negative': 31},
#    '청결도': {'positive': 5, 'negative': 1},
#    '재방문': {'positive': 5, 'negative': 0},
#    '속도': {'positive': 3, 'negative': 2},
#    '분위기': {'positive': 2, 'negative': 8}}},
#  '1123021012': {'store_name': '호랑이초밥 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 79, 'negative': 24},
#    '청결도': {'positive': 31, 'negative': 4},
#    '재방문': {'positive': 44, 'negative': 13},
#    '속도': {'positive': 4, 'negative': 0},
#    '분위기': {'positive': 19, 'negative': 10}}},
#  '34345158': {'store_name': '양재정육식당 3호점',
#   'aspect_sentiments': {'가성비': {'positive': 12, 'negative': 20},
#    '청결도': {'positive': 1, 'negative': 6},
#    '재방문': {'positive': 5, 'negative': 2},
#    '속도': {'positive': 2, 'negative': 3},
#    '분위기': {'positive': 5, 'negative': 2}}},
#  '37889898': {'store_name': '콩뿌리콩나물국밥 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 16, 'negative': 22},
#    '청결도': {'positive': 3, 'negative': 1},
#    '재방문': {'positive': 5, 'negative': 4},
#    '속도': {'positive': 4, 'negative': 1},
#    '분위기': {'positive': 0, 'negative': 4}}},
#  '13376678': {'store_name': '한솥도시락 양재교육개발원입구점',
#   'aspect_sentiments': {'가성비': {'positive': 32, 'negative': 12},
#    '청결도': {'positive': 4, 'negative': 3},
#    '재방문': {'positive': 3, 'negative': 1},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 0, 'negative': 0}}},
#  '1830398009': {'store_name': '서리풀돈까스',
#   'aspect_sentiments': {'가성비': {'positive': 21, 'negative': 14},
#    '청결도': {'positive': 3, 'negative': 3},
#    '재방문': {'positive': 4, 'negative': 6},
#    '속도': {'positive': 7, 'negative': 3},
#    '분위기': {'positive': 3, 'negative': 0}}},
#  '37307613': {'store_name': '양재오제섞어 양재본점',
#   'aspect_sentiments': {'가성비': {'positive': 51, 'negative': 84},
#    '청결도': {'positive': 8, 'negative': 6},
#    '재방문': {'positive': 16, 'negative': 11},
#    '속도': {'positive': 10, 'negative': 13},
#    '분위기': {'positive': 2, 'negative': 3}}},
#  '1927679596': {'store_name': '에베레스트 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 71, 'negative': 40},
#    '청결도': {'positive': 13, 'negative': 3},
#    '재방문': {'positive': 82, 'negative': 11},
#    '속도': {'positive': 6, 'negative': 3},
#    '분위기': {'positive': 23, 'negative': 12}}},
#  '1886378828': {'store_name': '곱창왕김형제 양재역본점',
#   'aspect_sentiments': {'가성비': {'positive': 33, 'negative': 48},
#    '청결도': {'positive': 9, 'negative': 6},
#    '재방문': {'positive': 25, 'negative': 5},
#    '속도': {'positive': 7, 'negative': 8},
#    '분위기': {'positive': 3, 'negative': 3}}},
#  '1891561259': {'store_name': '월계랑',
#   'aspect_sentiments': {'가성비': {'positive': 33, 'negative': 10},
#    '청결도': {'positive': 14, 'negative': 1},
#    '재방문': {'positive': 25, 'negative': 1},
#    '속도': {'positive': 1, 'negative': 4},
#    '분위기': {'positive': 8, 'negative': 2}}},
#  '1278613093': {'store_name': '지세포세꼬시',
#   'aspect_sentiments': {'가성비': {'positive': 14, 'negative': 14},
#    '청결도': {'positive': 0, 'negative': 3},
#    '재방문': {'positive': 6, 'negative': 2},
#    '속도': {'positive': 2, 'negative': 5},
#    '분위기': {'positive': 4, 'negative': 7}}},
#  '13348519': {'store_name': '타이쇼',
#   'aspect_sentiments': {'가성비': {'positive': 121, 'negative': 101},
#    '청결도': {'positive': 19, 'negative': 5},
#    '재방문': {'positive': 111, 'negative': 12},
#    '속도': {'positive': 22, 'negative': 22},
#    '분위기': {'positive': 126, 'negative': 62}}},
#  '1567180996': {'store_name': '에그드랍 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 10, 'negative': 4},
#    '청결도': {'positive': 4, 'negative': 0},
#    '재방문': {'positive': 0, 'negative': 3},
#    '속도': {'positive': 0, 'negative': 4},
#    '분위기': {'positive': 0, 'negative': 1}}},
#  '31186755': {'store_name': '아리노마마',
#   'aspect_sentiments': {'가성비': {'positive': 41, 'negative': 46},
#    '청결도': {'positive': 8, 'negative': 11},
#    '재방문': {'positive': 21, 'negative': 6},
#    '속도': {'positive': 6, 'negative': 13},
#    '분위기': {'positive': 66, 'negative': 30}}},
#  '1807443956': {'store_name': '양재역 조개맛집',
#   'aspect_sentiments': {'가성비': {'positive': 35, 'negative': 29},
#    '청결도': {'positive': 2, 'negative': 3},
#    '재방문': {'positive': 11, 'negative': 2},
#    '속도': {'positive': 1, 'negative': 1},
#    '분위기': {'positive': 17, 'negative': 11}}},
#  '1944962798': {'store_name': '이가네양꼬치 양재역직영점',
#   'aspect_sentiments': {'가성비': {'positive': 129, 'negative': 186},
#    '청결도': {'positive': 22, 'negative': 16},
#    '재방문': {'positive': 26, 'negative': 12},
#    '속도': {'positive': 40, 'negative': 43},
#    '분위기': {'positive': 13, 'negative': 8}}},
#  '31600260': {'store_name': '잰부닥',
#   'aspect_sentiments': {'가성비': {'positive': 39, 'negative': 75},
#    '청결도': {'positive': 5, 'negative': 8},
#    '재방문': {'positive': 14, 'negative': 10},
#    '속도': {'positive': 8, 'negative': 16},
#    '분위기': {'positive': 10, 'negative': 19}}},
#  '234208683': {'store_name': '양인환대',
#   'aspect_sentiments': {'가성비': {'positive': 104, 'negative': 149},
#    '청결도': {'positive': 25, 'negative': 18},
#    '재방문': {'positive': 18, 'negative': 12},
#    '속도': {'positive': 12, 'negative': 21},
#    '분위기': {'positive': 55, 'negative': 26}}},
#  '38474259': {'store_name': '오향절면 양재본점',
#   'aspect_sentiments': {'가성비': {'positive': 57, 'negative': 39},
#    '청결도': {'positive': 21, 'negative': 6},
#    '재방문': {'positive': 23, 'negative': 5},
#    '속도': {'positive': 10, 'negative': 7},
#    '분위기': {'positive': 5, 'negative': 9}}},
#  '1672141709': {'store_name': '육즙관리소 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 65, 'negative': 61},
#    '청결도': {'positive': 76, 'negative': 50},
#    '재방문': {'positive': 93, 'negative': 31},
#    '속도': {'positive': 16, 'negative': 21},
#    '분위기': {'positive': 108, 'negative': 73}}},
#  '1658172503': {'store_name': '닭곰탱이 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 47, 'negative': 29},
#    '청결도': {'positive': 3, 'negative': 3},
#    '재방문': {'positive': 3, 'negative': 1},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 8, 'negative': 2}}},
#  '1037966057': {'store_name': '피끄니크',
#   'aspect_sentiments': {'가성비': {'positive': 84, 'negative': 56},
#    '청결도': {'positive': 22, 'negative': 7},
#    '재방문': {'positive': 40, 'negative': 18},
#    '속도': {'positive': 12, 'negative': 10},
#    '분위기': {'positive': 28, 'negative': 12}}},
#  '1786476142': {'store_name': '로마옥 도곡',
#   'aspect_sentiments': {'가성비': {'positive': 24, 'negative': 44},
#    '청결도': {'positive': 4, 'negative': 0},
#    '재방문': {'positive': 17, 'negative': 3},
#    '속도': {'positive': 8, 'negative': 12},
#    '분위기': {'positive': 86, 'negative': 50}}},
#  '36538658': {'store_name': '니혼슈바 슈토',
#   'aspect_sentiments': {'가성비': {'positive': 72, 'negative': 50},
#    '청결도': {'positive': 7, 'negative': 4},
#    '재방문': {'positive': 22, 'negative': 10},
#    '속도': {'positive': 4, 'negative': 17},
#    '분위기': {'positive': 49, 'negative': 32}}},
#  '20897027': {'store_name': '작은공간',
#   'aspect_sentiments': {'가성비': {'positive': 52, 'negative': 50},
#    '청결도': {'positive': 5, 'negative': 8},
#    '재방문': {'positive': 18, 'negative': 8},
#    '속도': {'positive': 20, 'negative': 21},
#    '분위기': {'positive': 8, 'negative': 8}}},
#  '37615410': {'store_name': '신전떡볶이 도곡점',
#   'aspect_sentiments': {'가성비': {'positive': 12, 'negative': 8},
#    '청결도': {'positive': 1, 'negative': 2},
#    '재방문': {'positive': 9, 'negative': 1},
#    '속도': {'positive': 1, 'negative': 1},
#    '분위기': {'positive': 0, 'negative': 1}}},
#  '35155951': {'store_name': '국미당',
#   'aspect_sentiments': {'가성비': {'positive': 25, 'negative': 59},
#    '청결도': {'positive': 8, 'negative': 12},
#    '재방문': {'positive': 9, 'negative': 4},
#    '속도': {'positive': 4, 'negative': 16},
#    '분위기': {'positive': 1, 'negative': 5}}},
#  '1034622849': {'store_name': '국고집',
#   'aspect_sentiments': {'가성비': {'positive': 253, 'negative': 143},
#    '청결도': {'positive': 41, 'negative': 20},
#    '재방문': {'positive': 77, 'negative': 25},
#    '속도': {'positive': 18, 'negative': 15},
#    '분위기': {'positive': 32, 'negative': 48}}},
#  '30922907': {'store_name': '스파게티스토리',
#   'aspect_sentiments': {'가성비': {'positive': 39, 'negative': 35},
#    '청결도': {'positive': 1, 'negative': 8},
#    '재방문': {'positive': 5, 'negative': 1},
#    '속도': {'positive': 5, 'negative': 3},
#    '분위기': {'positive': 1, 'negative': 1}}},
#  '20601502': {'store_name': '그린네 은쟁반',
#   'aspect_sentiments': {'가성비': {'positive': 26, 'negative': 28},
#    '청결도': {'positive': 3, 'negative': 4},
#    '재방문': {'positive': 6, 'negative': 5},
#    '속도': {'positive': 2, 'negative': 4},
#    '분위기': {'positive': 0, 'negative': 1}}},
#  '1889974700': {'store_name': '마라홀릭 마라탕 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 36, 'negative': 22},
#    '청결도': {'positive': 16, 'negative': 1},
#    '재방문': {'positive': 52, 'negative': 2},
#    '속도': {'positive': 8, 'negative': 3},
#    '분위기': {'positive': 5, 'negative': 2}}},
#  '1672897084': {'store_name': '본죽&비빔밥cafe 양재은광여고점',
#   'aspect_sentiments': {'가성비': {'positive': 22, 'negative': 15},
#    '청결도': {'positive': 18, 'negative': 3},
#    '재방문': {'positive': 11, 'negative': 4},
#    '속도': {'positive': 11, 'negative': 14},
#    '분위기': {'positive': 4, 'negative': 1}}},
#  '35307516': {'store_name': '제레미버거',
#   'aspect_sentiments': {'가성비': {'positive': 34, 'negative': 38},
#    '청결도': {'positive': 5, 'negative': 2},
#    '재방문': {'positive': 10, 'negative': 6},
#    '속도': {'positive': 10, 'negative': 12},
#    '분위기': {'positive': 1, 'negative': 3}}},
#  '34098856': {'store_name': '얌얌 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 21, 'negative': 16},
#    '청결도': {'positive': 4, 'negative': 8},
#    '재방문': {'positive': 15, 'negative': 3},
#    '속도': {'positive': 12, 'negative': 5},
#    '분위기': {'positive': 0, 'negative': 1}}},
#  '12950069': {'store_name': '디오디아2.0',
#   'aspect_sentiments': {'가성비': {'positive': 186, 'negative': 143},
#    '청결도': {'positive': 39, 'negative': 14},
#    '재방문': {'positive': 79, 'negative': 21},
#    '속도': {'positive': 44, 'negative': 52},
#    '분위기': {'positive': 121, 'negative': 75}}},
#  '1664070278': {'store_name': '용짜장 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 15, 'negative': 13},
#    '청결도': {'positive': 1, 'negative': 1},
#    '재방문': {'positive': 2, 'negative': 0},
#    '속도': {'positive': 1, 'negative': 0},
#    '분위기': {'positive': 0, 'negative': 0}}},
#  '1154400830': {'store_name': '깐부치킨 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 16, 'negative': 26},
#    '청결도': {'positive': 0, 'negative': 3},
#    '재방문': {'positive': 4, 'negative': 3},
#    '속도': {'positive': 3, 'negative': 7},
#    '분위기': {'positive': 8, 'negative': 2}}},
#  '33459979': {'store_name': '치킨처럼 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 30, 'negative': 26},
#    '청결도': {'positive': 1, 'negative': 0},
#    '재방문': {'positive': 1, 'negative': 2},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 1, 'negative': 4}}},
#  '32699962': {'store_name': '장수정육식당',
#   'aspect_sentiments': {'가성비': {'positive': 13, 'negative': 5},
#    '청결도': {'positive': 1, 'negative': 2},
#    '재방문': {'positive': 1, 'negative': 0},
#    '속도': {'positive': 2, 'negative': 2},
#    '분위기': {'positive': 2, 'negative': 0}}},
#  '1069491314': {'store_name': '뎁짜이 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 37, 'negative': 18},
#    '청결도': {'positive': 20, 'negative': 1},
#    '재방문': {'positive': 32, 'negative': 8},
#    '속도': {'positive': 8, 'negative': 9},
#    '분위기': {'positive': 11, 'negative': 4}}},
#  '19882315': {'store_name': '자인뭉티기',
#   'aspect_sentiments': {'가성비': {'positive': 29, 'negative': 43},
#    '청결도': {'positive': 4, 'negative': 0},
#    '재방문': {'positive': 19, 'negative': 0},
#    '속도': {'positive': 11, 'negative': 8},
#    '분위기': {'positive': 12, 'negative': 12}}},
#  '1081786133': {'store_name': '훅트포케 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 59, 'negative': 40},
#    '청결도': {'positive': 28, 'negative': 4},
#    '재방문': {'positive': 41, 'negative': 5},
#    '속도': {'positive': 3, 'negative': 5},
#    '분위기': {'positive': 22, 'negative': 3}}},
#  '1625687301': {'store_name': '힐튼가든인 서울강남 가든 비스트로',
#   'aspect_sentiments': {'가성비': {'positive': 128, 'negative': 105},
#    '청결도': {'positive': 43, 'negative': 10},
#    '재방문': {'positive': 46, 'negative': 29},
#    '속도': {'positive': 12, 'negative': 27},
#    '분위기': {'positive': 91, 'negative': 53}}},
#  '38643869': {'store_name': '양지수제샌드위치',
#   'aspect_sentiments': {'가성비': {'positive': 9, 'negative': 27},
#    '청결도': {'positive': 5, 'negative': 3},
#    '재방문': {'positive': 5, 'negative': 5},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 7, 'negative': 1}}},
#  '36868411': {'store_name': '순남시래기 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 53, 'negative': 38},
#    '청결도': {'positive': 10, 'negative': 4},
#    '재방문': {'positive': 13, 'negative': 6},
#    '속도': {'positive': 13, 'negative': 8},
#    '분위기': {'positive': 2, 'negative': 3}}},
#  '20874669': {'store_name': '황재벌 본점',
#   'aspect_sentiments': {'가성비': {'positive': 86, 'negative': 110},
#    '청결도': {'positive': 3, 'negative': 11},
#    '재방문': {'positive': 17, 'negative': 6},
#    '속도': {'positive': 36, 'negative': 41},
#    '분위기': {'positive': 4, 'negative': 8}}},
#  '13157782': {'store_name': '늘봄족발보쌈',
#   'aspect_sentiments': {'가성비': {'positive': 22, 'negative': 4},
#    '청결도': {'positive': 2, 'negative': 0},
#    '재방문': {'positive': 5, 'negative': 3},
#    '속도': {'positive': 1, 'negative': 0},
#    '분위기': {'positive': 0, 'negative': 3}}},
#  '1192671730': {'store_name': '오부찌 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 67, 'negative': 41},
#    '청결도': {'positive': 15, 'negative': 7},
#    '재방문': {'positive': 19, 'negative': 8},
#    '속도': {'positive': 13, 'negative': 8},
#    '분위기': {'positive': 3, 'negative': 2}}},
#  '38591616': {'store_name': '고양이부엌 양재구청점',
#   'aspect_sentiments': {'가성비': {'positive': 65, 'negative': 40},
#    '청결도': {'positive': 5, 'negative': 7},
#    '재방문': {'positive': 6, 'negative': 8},
#    '속도': {'positive': 3, 'negative': 8},
#    '분위기': {'positive': 12, 'negative': 1}}},
#  '1320179295': {'store_name': '크라이치즈버거 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 16, 'negative': 33},
#    '청결도': {'positive': 11, 'negative': 2},
#    '재방문': {'positive': 4, 'negative': 5},
#    '속도': {'positive': 0, 'negative': 1},
#    '분위기': {'positive': 4, 'negative': 1}}},
#  '11861500': {'store_name': '전주옛날집',
#   'aspect_sentiments': {'가성비': {'positive': 17, 'negative': 14},
#    '청결도': {'positive': 4, 'negative': 3},
#    '재방문': {'positive': 1, 'negative': 3},
#    '속도': {'positive': 3, 'negative': 2},
#    '분위기': {'positive': 5, 'negative': 9}}},
#  '1078767514': {'store_name': '서초목살',
#   'aspect_sentiments': {'가성비': {'positive': 24, 'negative': 12},
#    '청결도': {'positive': 3, 'negative': 0},
#    '재방문': {'positive': 44, 'negative': 1},
#    '속도': {'positive': 6, 'negative': 1},
#    '분위기': {'positive': 5, 'negative': 7}}},
#  '31134978': {'store_name': '본도시락 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 13, 'negative': 8},
#    '청결도': {'positive': 3, 'negative': 1},
#    '재방문': {'positive': 3, 'negative': 0},
#    '속도': {'positive': 5, 'negative': 1},
#    '분위기': {'positive': 0, 'negative': 1}}},
#  '18771333': {'store_name': '진스시',
#   'aspect_sentiments': {'가성비': {'positive': 91, 'negative': 78},
#    '청결도': {'positive': 45, 'negative': 6},
#    '재방문': {'positive': 23, 'negative': 12},
#    '속도': {'positive': 14, 'negative': 19},
#    '분위기': {'positive': 81, 'negative': 42}}},
#  '37997726': {'store_name': '봉피양 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 105, 'negative': 140},
#    '청결도': {'positive': 12, 'negative': 12},
#    '재방문': {'positive': 3, 'negative': 5},
#    '속도': {'positive': 8, 'negative': 29},
#    '분위기': {'positive': 20, 'negative': 20}}},
#  '37236849': {'store_name': '돼지연구소 양재직영점',
#   'aspect_sentiments': {'가성비': {'positive': 16, 'negative': 27},
#    '청결도': {'positive': 7, 'negative': 1},
#    '재방문': {'positive': 27, 'negative': 7},
#    '속도': {'positive': 11, 'negative': 11},
#    '분위기': {'positive': 6, 'negative': 5}}},
#  '1268565080': {'store_name': '솥두껍 양재본점',
#   'aspect_sentiments': {'가성비': {'positive': 260, 'negative': 198},
#    '청결도': {'positive': 21, 'negative': 11},
#    '재방문': {'positive': 104, 'negative': 24},
#    '속도': {'positive': 17, 'negative': 23},
#    '분위기': {'positive': 15, 'negative': 14}}},
#  '37902481': {'store_name': '깡돈',
#   'aspect_sentiments': {'가성비': {'positive': 28, 'negative': 13},
#    '청결도': {'positive': 0, 'negative': 1},
#    '재방문': {'positive': 5, 'negative': 0},
#    '속도': {'positive': 3, 'negative': 0},
#    '분위기': {'positive': 1, 'negative': 0}}},
#  '32821881': {'store_name': '토봉추어탕',
#   'aspect_sentiments': {'가성비': {'positive': 28, 'negative': 29},
#    '청결도': {'positive': 14, 'negative': 8},
#    '재방문': {'positive': 18, 'negative': 6},
#    '속도': {'positive': 6, 'negative': 5},
#    '분위기': {'positive': 4, 'negative': 0}}},
#  '1044461398': {'store_name': '우대포 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 213, 'negative': 106},
#    '청결도': {'positive': 55, 'negative': 10},
#    '재방문': {'positive': 94, 'negative': 16},
#    '속도': {'positive': 24, 'negative': 20},
#    '분위기': {'positive': 24, 'negative': 13}}},
#  '11627634': {'store_name': '버드나무집 서초동본점',
#   'aspect_sentiments': {'가성비': {'positive': 36, 'negative': 61},
#    '청결도': {'positive': 7, 'negative': 4},
#    '재방문': {'positive': 8, 'negative': 5},
#    '속도': {'positive': 3, 'negative': 4},
#    '분위기': {'positive': 6, 'negative': 11}}},
#  '18779141': {'store_name': '듬북담북 뱅뱅점',
#   'aspect_sentiments': {'가성비': {'positive': 12, 'negative': 8},
#    '청결도': {'positive': 4, 'negative': 2},
#    '재방문': {'positive': 8, 'negative': 2},
#    '속도': {'positive': 1, 'negative': 0},
#    '분위기': {'positive': 2, 'negative': 6}}},
#  '98898756': {'store_name': '양재정육식당 역삼뱅뱅점',
#   'aspect_sentiments': {'가성비': {'positive': 64, 'negative': 51},
#    '청결도': {'positive': 4, 'negative': 3},
#    '재방문': {'positive': 11, 'negative': 2},
#    '속도': {'positive': 3, 'negative': 4},
#    '분위기': {'positive': 4, 'negative': 6}}},
#  '13150366': {'store_name': '참설농탕 서초점',
#   'aspect_sentiments': {'가성비': {'positive': 17, 'negative': 63},
#    '청결도': {'positive': 9, 'negative': 11},
#    '재방문': {'positive': 20, 'negative': 10},
#    '속도': {'positive': 9, 'negative': 9},
#    '분위기': {'positive': 0, 'negative': 2}}},
#  '1550997885': {'store_name': '부안애서 서초점',
#   'aspect_sentiments': {'가성비': {'positive': 97, 'negative': 50},
#    '청결도': {'positive': 53, 'negative': 8},
#    '재방문': {'positive': 55, 'negative': 17},
#    '속도': {'positive': 14, 'negative': 11},
#    '분위기': {'positive': 41, 'negative': 22}}},
#  '34582729': {'store_name': '담소소사골순대육개장 서초점',
#   'aspect_sentiments': {'가성비': {'positive': 25, 'negative': 12},
#    '청결도': {'positive': 8, 'negative': 3},
#    '재방문': {'positive': 5, 'negative': 4},
#    '속도': {'positive': 2, 'negative': 3},
#    '분위기': {'positive': 1, 'negative': 1}}},
#  '18361460': {'store_name': '광양참숯불고기',
#   'aspect_sentiments': {'가성비': {'positive': 28, 'negative': 40},
#    '청결도': {'positive': 13, 'negative': 6},
#    '재방문': {'positive': 8, 'negative': 4},
#    '속도': {'positive': 1, 'negative': 3},
#    '분위기': {'positive': 6, 'negative': 7}}},
#  '1532111915': {'store_name': '푸라닭 서초2동점',
#   'aspect_sentiments': {'가성비': {'positive': 9, 'negative': 9},
#    '청결도': {'positive': 7, 'negative': 2},
#    '재방문': {'positive': 8, 'negative': 2},
#    '속도': {'positive': 5, 'negative': 2},
#    '분위기': {'positive': 1, 'negative': 6}}},
#  '1925656389': {'store_name': '피넘타이',
#   'aspect_sentiments': {'가성비': {'positive': 38, 'negative': 27},
#    '청결도': {'positive': 16, 'negative': 3},
#    '재방문': {'positive': 24, 'negative': 3},
#    '속도': {'positive': 6, 'negative': 5},
#    '분위기': {'positive': 19, 'negative': 2}}},
#  '20083769': {'store_name': '전사랑 서초본점',
#   'aspect_sentiments': {'가성비': {'positive': 73, 'negative': 59},
#    '청결도': {'positive': 16, 'negative': 3},
#    '재방문': {'positive': 25, 'negative': 4},
#    '속도': {'positive': 6, 'negative': 11},
#    '분위기': {'positive': 14, 'negative': 7}}},
#  '1137666363': {'store_name': '옥된장 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 29, 'negative': 16},
#    '청결도': {'positive': 12, 'negative': 2},
#    '재방문': {'positive': 13, 'negative': 2},
#    '속도': {'positive': 3, 'negative': 1},
#    '분위기': {'positive': 11, 'negative': 3}}},
#  '1553486347': {'store_name': '마라두목 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 30, 'negative': 14},
#    '청결도': {'positive': 32, 'negative': 7},
#    '재방문': {'positive': 24, 'negative': 3},
#    '속도': {'positive': 9, 'negative': 3},
#    '분위기': {'positive': 14, 'negative': 1}}},
#  '1688755338': {'store_name': '백소정 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 64, 'negative': 16},
#    '청결도': {'positive': 50, 'negative': 9},
#    '재방문': {'positive': 40, 'negative': 5},
#    '속도': {'positive': 13, 'negative': 15},
#    '분위기': {'positive': 8, 'negative': 3}}},
#  '1516711006': {'store_name': '불로삼계백숙',
#   'aspect_sentiments': {'가성비': {'positive': 53, 'negative': 35},
#    '청결도': {'positive': 9, 'negative': 5},
#    '재방문': {'positive': 14, 'negative': 7},
#    '속도': {'positive': 3, 'negative': 5},
#    '분위기': {'positive': 7, 'negative': 3}}},
#  '1932467805': {'store_name': '보글이 생태탕왕코다리 양재역점',
#   'aspect_sentiments': {'가성비': {'positive': 182, 'negative': 82},
#    '청결도': {'positive': 25, 'negative': 2},
#    '재방문': {'positive': 40, 'negative': 12},
#    '속도': {'positive': 11, 'negative': 12},
#    '분위기': {'positive': 15, 'negative': 8}}},
#  '1698302178': {'store_name': '도화',
#   'aspect_sentiments': {'가성비': {'positive': 48, 'negative': 31},
#    '청결도': {'positive': 17, 'negative': 4},
#    '재방문': {'positive': 18, 'negative': 4},
#    '속도': {'positive': 5, 'negative': 7},
#    '분위기': {'positive': 15, 'negative': 6}}},
#  '1751873950': {'store_name': '양재순대',
#   'aspect_sentiments': {'가성비': {'positive': 49, 'negative': 46},
#    '청결도': {'positive': 12, 'negative': 13},
#    '재방문': {'positive': 8, 'negative': 7},
#    '속도': {'positive': 18, 'negative': 21},
#    '분위기': {'positive': 6, 'negative': 3}}},
#  '18307489': {'store_name': '어부참치',
#   'aspect_sentiments': {'가성비': {'positive': 5, 'negative': 14},
#    '청결도': {'positive': 4, 'negative': 1},
#    '재방문': {'positive': 4, 'negative': 1},
#    '속도': {'positive': 1, 'negative': 2},
#    '분위기': {'positive': 1, 'negative': 0}}},
#  '1941253545': {'store_name': 'Poke all day 포케&샐러드 양재점',
#   'aspect_sentiments': {'가성비': {'positive': 77, 'negative': 70},
#    '청결도': {'positive': 56, 'negative': 4},
#    '재방문': {'positive': 48, 'negative': 10},
#    '속도': {'positive': 9, 'negative': 1},
#    '분위기': {'positive': 18, 'negative': 6}}},
#  '1827894067': {'store_name': '명가무안뻘낙지',
#   'aspect_sentiments': {'가성비': {'positive': 7, 'negative': 24},
#    '청결도': {'positive': 1, 'negative': 9},
#    '재방문': {'positive': 6, 'negative': 2},
#    '속도': {'positive': 0, 'negative': 4},
#    '분위기': {'positive': 3, 'negative': 2}}},
#  '13150440': {'store_name': '콩나루콩나물국밥 직영점',
#   'aspect_sentiments': {'가성비': {'positive': 10, 'negative': 7},
#    '청결도': {'positive': 0, 'negative': 1},
#    '재방문': {'positive': 7, 'negative': 2},
#    '속도': {'positive': 3, 'negative': 2},
#    '분위기': {'positive': 0, 'negative': 0}}},
#  '1361137881': {'store_name': '채석강',
#   'aspect_sentiments': {'가성비': {'positive': 42, 'negative': 43},
#    '청결도': {'positive': 16, 'negative': 4},
#    '재방문': {'positive': 9, 'negative': 3},
#    '속도': {'positive': 3, 'negative': 6},
#    '분위기': {'positive': 4, 'negative': 0}}},
#  '1420055829': {'store_name': '임병주산동칼국수',
#   'aspect_sentiments': {'가성비': {'positive': 38, 'negative': 89},
#    '청결도': {'positive': 13, 'negative': 13},
#    '재방문': {'positive': 18, 'negative': 18},
#    '속도': {'positive': 40, 'negative': 41},
#    '분위기': {'positive': 11, 'negative': 13}}},
#  '1931613846': {'store_name': '우나유 나고야식 장어덮밥',
#   'aspect_sentiments': {'가성비': {'positive': 41, 'negative': 52},
#    '청결도': {'positive': 14, 'negative': 5},
#    '재방문': {'positive': 29, 'negative': 5},
#    '속도': {'positive': 9, 'negative': 11},
#    '분위기': {'positive': 25, 'negative': 12}}},
#  '36200001': {'store_name': '춘향골남원추어탕 서초점',
#   'aspect_sentiments': {'가성비': {'positive': 10, 'negative': 9},
#    '청결도': {'positive': 4, 'negative': 3},
#    '재방문': {'positive': 2, 'negative': 0},
#    '속도': {'positive': 1, 'negative': 1},
#    '분위기': {'positive': 0, 'negative': 0}}},
#  '13150444': {'store_name': '난랑',
#   'aspect_sentiments': {'가성비': {'positive': 42, 'negative': 52},
#    '청결도': {'positive': 12, 'negative': 5},
#    '재방문': {'positive': 19, 'negative': 4},
#    '속도': {'positive': 12, 'negative': 9},
#    '분위기': {'positive': 25, 'negative': 18}}}}

# %%
print(len(store_aspect_sentiments))
# Out:
# 134

# %%
# 결과를 JSON 형식으로 저장
with open('/content/drive/MyDrive/NaverCrawlingData/store_aspect_sentiments2.json', 'w', encoding='utf-8') as f:
    json.dump(store_aspect_sentiments, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # 키워드 별 점수 계산

# %%
import json
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# final_final_final_dataset.json 파일 로드
with open('/content/drive/MyDrive/NaverCrawlingData/final_final_final_dataset.json', 'r', encoding='utf-8') as f:
    final_dataset = json.load(f)

# store_aspect_sentiments2.json 파일 로드
with open('/content/drive/MyDrive/NaverCrawlingData/store_aspect_sentiments2.json', 'r', encoding='utf-8') as f:
    store_aspect_sentiments = json.load(f)

# 가게별 5가지 측면에 대한 점수를 저장할 리스트
store_scores = []

# 각 가게별 5개의 측면에 대해 점수 계산
for store in final_dataset:
    store_id = store['store_id']

    if store_id in store_aspect_sentiments:
        aspect_sentiments = store_aspect_sentiments[store_id]['aspect_sentiments']
        total_reviews = len(store['reviews'])  # 전체 리뷰 수

        # 각 측면에 대해 [(긍정 리뷰 수 - 부정 리뷰 수) / 전체 리뷰 수] * 100으로 점수 계산
        scores = {}
        for aspect, counts in aspect_sentiments.items():
            positive_count = counts['positive']
            negative_count = counts['negative']
            score = ((positive_count - negative_count) / total_reviews) * 100
            scores[aspect] = score

        # 가게별 점수를 저장
        store_scores.append({'store_id': store_id, 'store_name': store['store_info']['store_name'], 'scores': scores})

# 항목별 점수들을 추출해 정규화를 준비
aspects = ['가성비', '청결도', '재방문', '속도', '분위기']

# 항목별 점수들을 모아둔 딕셔너리
aspect_scores = {aspect: [] for aspect in aspects}

# 각 가게의 점수를 항목별로 추출
for store in store_scores:
    for aspect in aspects:
        aspect_scores[aspect].append(store['scores'][aspect])

# 항목별 정규화 (0 ~ 1 범위)
normalized_aspect_scores = {}
for aspect in aspects:
    min_score = min(aspect_scores[aspect])
    max_score = max(aspect_scores[aspect])
    # 정규화 및 소수점 셋째 자리까지 반올림
    normalized_aspect_scores[aspect] = [
        round((score - min_score) / (max_score - min_score), 3) if max_score != min_score else 0
        for score in aspect_scores[aspect]
    ]

# 각 가게별로 정규화된 점수를 저장
for i, store in enumerate(store_scores):
    for aspect in aspects:
        store['scores'][f'{aspect}_normalized'] = normalized_aspect_scores[aspect][i]

# 정규화된 점수를 원래 데이터셋에 추가
for store in final_dataset:
    store_id = store['store_id']

    # 해당 가게의 정규화된 점수를 찾아서 추가
    for normalized_store in store_scores:
        if store_id == normalized_store['store_id']:
            store['store_info']['scores'] = normalized_store['scores']

# %%
# 가게별로 점수 확인하는 코드
for store in final_dataset:
    store_id = store["store_id"]
    store_name = store["store_info"]["store_name"]
    scores = store["store_info"]["scores"]

    print(f"가게 ID: {store_id}, 가게 이름: {store_name}")
    print("점수 (정규화 전):")
    print(f"  가성비: {scores['가성비']}")
    print(f"  청결도: {scores['청결도']}")
    print(f"  재방문: {scores['재방문']}")
    print(f"  속도: {scores['속도']}")
    print(f"  분위기: {scores['분위기']}")

    print("정규화된 점수:")
    print(f"  가성비 (normalized): {scores['가성비_normalized']}")
    print(f"  청결도 (normalized): {scores['청결도_normalized']}")
    print(f"  재방문 (normalized): {scores['재방문_normalized']}")
    print(f"  속도 (normalized): {scores['속도_normalized']}")
    print(f"  분위기 (normalized): {scores['분위기_normalized']}")
    print("-" * 40)
# Out:
# 가게 ID: 1582818366, 가게 이름: 퀸즈가든 양재점
# 점수 (정규화 전):
#   가성비: 35.0
#   청결도: 14.374999999999998
#   재방문: 16.875
#   속도: -2.5
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.787
#   청결도 (normalized): 0.2
#   재방문 (normalized): 0.181
#   속도 (normalized): 0.5
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 37233088, 가게 이름: 갈비사랑 양재본점
# 점수 (정규화 전):
#   가성비: -27.77777777777778
#   청결도: 12.222222222222221
#   재방문: 8.88888888888889
#   속도: -6.666666666666667
#   분위기: 12.222222222222221
# 정규화된 점수:
#   가성비 (normalized): 0.0
#   청결도 (normalized): 0.181
#   재방문 (normalized): 0.111
#   속도 (normalized): 0.222
#   분위기 (normalized): 0.459
# ----------------------------------------
# 가게 ID: 38264349, 가게 이름: 한양돈까스
# 점수 (정규화 전):
#   가성비: -7.5
#   청결도: -1.25
#   재방문: 0.0
#   속도: -3.3333333333333335
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.254
#   청결도 (normalized): 0.06
#   재방문 (normalized): 0.033
#   속도 (normalized): 0.444
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1113983640, 가게 이름: 탐라순대국감자탕 양재역직영점
# 점수 (정규화 전):
#   가성비: 52.0
#   청결도: 104.0
#   재방문: 110.00000000000001
#   속도: 2.0
#   분위기: 12.0
# 정규화된 점수:
#   가성비 (normalized): 1.0
#   청결도 (normalized): 1.0
#   재방문 (normalized): 1.0
#   속도 (normalized): 0.8
#   분위기 (normalized): 0.453
# ----------------------------------------
# 가게 ID: 32254662, 가게 이름: 한국순대 본점
# 점수 (정규화 전):
#   가성비: -11.11111111111111
#   청결도: 0.3703703703703704
#   재방문: 2.9629629629629632
#   속도: -2.2222222222222223
#   분위기: 1.8518518518518516
# 정규화된 점수:
#   가성비 (normalized): 0.209
#   청결도 (normalized): 0.075
#   재방문 (normalized): 0.059
#   속도 (normalized): 0.519
#   분위기 (normalized): 0.185
# ----------------------------------------
# 가게 ID: 1427943416, 가게 이름: 고려향
# 점수 (정규화 전):
#   가성비: -12.727272727272727
#   청결도: 4.545454545454546
#   재방문: 4.545454545454546
#   속도: 1.8181818181818181
#   분위기: -1.8181818181818181
# 정규화된 점수:
#   가성비 (normalized): 0.189
#   청결도 (normalized): 0.112
#   재방문 (normalized): 0.073
#   속도 (normalized): 0.788
#   분위기 (normalized): 0.088
# ----------------------------------------
# 가게 ID: 1879800911, 가게 이름: 쿠니라멘
# 점수 (정규화 전):
#   가성비: 0.0
#   청결도: 0.0
#   재방문: 5.0
#   속도: 3.0
#   분위기: 2.0
# 정규화된 점수:
#   가성비 (normalized): 0.348
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.077
#   속도 (normalized): 0.867
#   분위기 (normalized): 0.189
# ----------------------------------------
# 가게 ID: 209145847, 가게 이름: 바다고기
# 점수 (정규화 전):
#   가성비: -17.441860465116278
#   청결도: 6.976744186046512
#   재방문: 0.0
#   속도: 1.1627906976744187
#   분위기: 3.488372093023256
# 정규화된 점수:
#   가성비 (normalized): 0.13
#   청결도 (normalized): 0.134
#   재방문 (normalized): 0.033
#   속도 (normalized): 0.744
#   분위기 (normalized): 0.228
# ----------------------------------------
# 가게 ID: 1838844768, 가게 이름: 노상치킨 양재점
# 점수 (정규화 전):
#   가성비: 16.666666666666664
#   청결도: -3.3333333333333335
#   재방문: 1.6666666666666667
#   속도: -1.6666666666666667
#   분위기: 3.3333333333333335
# 정규화된 점수:
#   가성비 (normalized): 0.557
#   청결도 (normalized): 0.042
#   재방문 (normalized): 0.048
#   속도 (normalized): 0.556
#   분위기 (normalized): 0.224
# ----------------------------------------
# 가게 ID: 1106978299, 가게 이름: 세광양대창 양재점
# 점수 (정규화 전):
#   가성비: 7.931034482758621
#   청결도: 1.7241379310344827
#   재방문: 12.758620689655173
#   속도: -1.0344827586206897
#   분위기: 8.96551724137931
# 정규화된 점수:
#   가성비 (normalized): 0.448
#   청결도 (normalized): 0.087
#   재방문 (normalized): 0.145
#   속도 (normalized): 0.598
#   분위기 (normalized): 0.373
# ----------------------------------------
# 가게 ID: 18747564, 가게 이름: 소부곱창
# 점수 (정규화 전):
#   가성비: -11.458333333333332
#   청결도: -2.083333333333333
#   재방문: 4.166666666666666
#   속도: -1.0416666666666665
#   분위기: -3.125
# 정규화된 점수:
#   가성비 (normalized): 0.205
#   청결도 (normalized): 0.053
#   재방문 (normalized): 0.07
#   속도 (normalized): 0.597
#   분위기 (normalized): 0.054
# ----------------------------------------
# 가게 ID: 964119437, 가게 이름: 스시썸
# 점수 (정규화 전):
#   가성비: 14.193548387096774
#   청결도: 4.838709677419355
#   재방문: 17.741935483870968
#   속도: 0.967741935483871
#   분위기: 14.193548387096774
# 정규화된 점수:
#   가성비 (normalized): 0.526
#   청결도 (normalized): 0.115
#   재방문 (normalized): 0.189
#   속도 (normalized): 0.731
#   분위기 (normalized): 0.511
# ----------------------------------------
# 가게 ID: 12981147, 가게 이름: 갈비세상 양재본점
# 점수 (정규화 전):
#   가성비: -11.428571428571429
#   청결도: 3.8095238095238098
#   재방문: 5.714285714285714
#   속도: -4.285714285714286
#   분위기: 1.4285714285714286
# 정규화된 점수:
#   가성비 (normalized): 0.205
#   청결도 (normalized): 0.105
#   재방문 (normalized): 0.083
#   속도 (normalized): 0.381
#   분위기 (normalized): 0.174
# ----------------------------------------
# 가게 ID: 46696494, 가게 이름: 태국식당356
# 점수 (정규화 전):
#   가성비: 0.967741935483871
#   청결도: 3.225806451612903
#   재방문: 7.096774193548387
#   속도: -1.935483870967742
#   분위기: 0.6451612903225806
# 정규화된 점수:
#   가성비 (normalized): 0.36
#   청결도 (normalized): 0.1
#   재방문 (normalized): 0.095
#   속도 (normalized): 0.538
#   분위기 (normalized): 0.153
# ----------------------------------------
# 가게 ID: 38229207, 가게 이름: 만복국수집 양재점
# 점수 (정규화 전):
#   가성비: 2.6881720430107525
#   청결도: 0.0
#   재방문: 1.6129032258064515
#   속도: -0.5376344086021506
#   분위기: -0.5376344086021506
# 정규화된 점수:
#   가성비 (normalized): 0.382
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.047
#   속도 (normalized): 0.631
#   분위기 (normalized): 0.122
# ----------------------------------------
# 가게 ID: 179368379, 가게 이름: 24시찹쌀순대만드는집
# 점수 (정규화 전):
#   가성비: -3.4615384615384617
#   청결도: -1.9230769230769231
#   재방문: -1.153846153846154
#   속도: -0.38461538461538464
#   분위기: 0.38461538461538464
# 정규화된 점수:
#   가성비 (normalized): 0.305
#   청결도 (normalized): 0.054
#   재방문 (normalized): 0.023
#   속도 (normalized): 0.641
#   분위기 (normalized): 0.146
# ----------------------------------------
# 가게 ID: 1188227652, 가게 이름: 소곰집 양재점
# 점수 (정규화 전):
#   가성비: 22.857142857142858
#   청결도: 0.9523809523809524
#   재방문: 10.476190476190476
#   속도: -0.9523809523809524
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.635
#   청결도 (normalized): 0.08
#   재방문 (normalized): 0.125
#   속도 (normalized): 0.603
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 32708325, 가게 이름: 강촌원조쭈꾸미본점
# 점수 (정규화 전):
#   가성비: -10.952380952380953
#   청결도: -1.4285714285714286
#   재방문: 3.3333333333333335
#   속도: -6.190476190476191
#   분위기: 2.380952380952381
# 정규화된 점수:
#   가성비 (normalized): 0.211
#   청결도 (normalized): 0.059
#   재방문 (normalized): 0.062
#   속도 (normalized): 0.254
#   분위기 (normalized): 0.199
# ----------------------------------------
# 가게 ID: 38248908, 가게 이름: 치킨영토 양재점
# 점수 (정규화 전):
#   가성비: -6.578947368421052
#   청결도: 0.6578947368421052
#   재방문: 0.6578947368421052
#   속도: -1.3157894736842104
#   분위기: 0.6578947368421052
# 정규화된 점수:
#   가성비 (normalized): 0.266
#   청결도 (normalized): 0.077
#   재방문 (normalized): 0.039
#   속도 (normalized): 0.579
#   분위기 (normalized): 0.154
# ----------------------------------------
# 가게 ID: 12962167, 가게 이름: 라그릴리아 양재점
# 점수 (정규화 전):
#   가성비: -6.315789473684211
#   청결도: 0.0
#   재방문: 3.684210526315789
#   속도: -5.7894736842105265
#   분위기: 12.105263157894736
# 정규화된 점수:
#   가성비 (normalized): 0.269
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.065
#   속도 (normalized): 0.281
#   분위기 (normalized): 0.456
# ----------------------------------------
# 가게 ID: 1735144615, 가게 이름: 이층완우
# 점수 (정규화 전):
#   가성비: 2.5
#   청결도: 10.416666666666668
#   재방문: 13.333333333333334
#   속도: -0.8333333333333334
#   분위기: 14.583333333333334
# 정규화된 점수:
#   가성비 (normalized): 0.38
#   청결도 (normalized): 0.164
#   재방문 (normalized): 0.15
#   속도 (normalized): 0.611
#   분위기 (normalized): 0.521
# ----------------------------------------
# 가게 ID: 193891932, 가게 이름: 화차이
# 점수 (정규화 전):
#   가성비: -10.0
#   청결도: -0.4166666666666667
#   재방문: 3.3333333333333335
#   속도: 3.3333333333333335
#   분위기: -1.25
# 정규화된 점수:
#   가성비 (normalized): 0.223
#   청결도 (normalized): 0.068
#   재방문 (normalized): 0.062
#   속도 (normalized): 0.889
#   분위기 (normalized): 0.103
# ----------------------------------------
# 가게 ID: 1906380511, 가게 이름: 손수동
# 점수 (정규화 전):
#   가성비: 7.333333333333333
#   청결도: 8.0
#   재방문: 18.333333333333332
#   속도: 2.3333333333333335
#   분위기: 4.333333333333334
# 정규화된 점수:
#   가성비 (normalized): 0.44
#   청결도 (normalized): 0.143
#   재방문 (normalized): 0.194
#   속도 (normalized): 0.822
#   분위기 (normalized): 0.251
# ----------------------------------------
# 가게 ID: 1360440438, 가게 이름: 미몽 양재역점
# 점수 (정규화 전):
#   가성비: 7.857142857142857
#   청결도: 3.571428571428571
#   재방문: 18.571428571428573
#   속도: 5.0
#   분위기: 5.0
# 정규화된 점수:
#   가성비 (normalized): 0.447
#   청결도 (normalized): 0.103
#   재방문 (normalized): 0.196
#   속도 (normalized): 1.0
#   분위기 (normalized): 0.268
# ----------------------------------------
# 가게 ID: 74715630, 가게 이름: 배수경양재정육식당 9호점
# 점수 (정규화 전):
#   가성비: -17.46031746031746
#   청결도: -1.5873015873015872
#   재방문: 2.1164021164021163
#   속도: -2.1164021164021163
#   분위기: -1.0582010582010581
# 정규화된 점수:
#   가성비 (normalized): 0.129
#   청결도 (normalized): 0.057
#   재방문 (normalized): 0.052
#   속도 (normalized): 0.526
#   분위기 (normalized): 0.108
# ----------------------------------------
# 가게 ID: 13151847, 가게 이름: 돈오리
# 점수 (정규화 전):
#   가성비: -3.4482758620689653
#   청결도: 2.2988505747126435
#   재방문: 3.4482758620689653
#   속도: 0.0
#   분위기: 2.2988505747126435
# 정규화된 점수:
#   가성비 (normalized): 0.305
#   청결도 (normalized): 0.092
#   재방문 (normalized): 0.063
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.197
# ----------------------------------------
# 가게 ID: 1660867179, 가게 이름: 진여사댁
# 점수 (정규화 전):
#   가성비: 5.333333333333334
#   청결도: 3.6666666666666665
#   재방문: 13.0
#   속도: -2.666666666666667
#   분위기: 5.0
# 정규화된 점수:
#   가성비 (normalized): 0.415
#   청결도 (normalized): 0.104
#   재방문 (normalized): 0.147
#   속도 (normalized): 0.489
#   분위기 (normalized): 0.268
# ----------------------------------------
# 가게 ID: 151264987, 가게 이름: 하우림 양재점
# 점수 (정규화 전):
#   가성비: -0.45454545454545453
#   청결도: 4.090909090909091
#   재방문: 0.45454545454545453
#   속도: -0.45454545454545453
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.342
#   청결도 (normalized): 0.108
#   재방문 (normalized): 0.037
#   속도 (normalized): 0.636
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 35136252, 가게 이름: 양재닭집
# 점수 (정규화 전):
#   가성비: -1.6129032258064515
#   청결도: -1.935483870967742
#   재방문: 2.258064516129032
#   속도: -0.967741935483871
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.328
#   청결도 (normalized): 0.054
#   재방문 (normalized): 0.053
#   속도 (normalized): 0.602
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1257299870, 가게 이름: 곰작골나주곰탕 양재점
# 점수 (정규화 전):
#   가성비: -8.064516129032258
#   청결도: 5.161290322580645
#   재방문: 2.903225806451613
#   속도: -1.935483870967742
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.247
#   청결도 (normalized): 0.118
#   재방문 (normalized): 0.058
#   속도 (normalized): 0.538
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 12917286, 가게 이름: 영동족발 본점
# 점수 (정규화 전):
#   가성비: -3.103448275862069
#   청결도: -1.3793103448275863
#   재방문: 0.6896551724137931
#   속도: -2.413793103448276
#   분위기: 0.3448275862068966
# 정규화된 점수:
#   가성비 (normalized): 0.309
#   청결도 (normalized): 0.059
#   재방문 (normalized): 0.039
#   속도 (normalized): 0.506
#   분위기 (normalized): 0.145
# ----------------------------------------
# 가게 ID: 573699969, 가게 이름: 오선채
# 점수 (정규화 전):
#   가성비: -7.647058823529412
#   청결도: 5.88235294117647
#   재방문: 4.117647058823529
#   속도: 0.0
#   분위기: -1.1764705882352942
# 정규화된 점수:
#   가성비 (normalized): 0.252
#   청결도 (normalized): 0.124
#   재방문 (normalized): 0.069
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.105
# ----------------------------------------
# 가게 ID: 620225564, 가게 이름: 김치뚝딱 양재점
# 점수 (정규화 전):
#   가성비: -6.862745098039216
#   청결도: 1.9607843137254901
#   재방문: -0.9803921568627451
#   속도: 0.0
#   분위기: 0.9803921568627451
# 정규화된 점수:
#   가성비 (normalized): 0.262
#   청결도 (normalized): 0.089
#   재방문 (normalized): 0.024
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.162
# ----------------------------------------
# 가게 ID: 38709080, 가게 이름: 백화네부엌
# 점수 (정규화 전):
#   가성비: 5.238095238095238
#   청결도: 4.761904761904762
#   재방문: 4.285714285714286
#   속도: -0.4761904761904762
#   분위기: -0.9523809523809524
# 정규화된 점수:
#   가성비 (normalized): 0.414
#   청결도 (normalized): 0.114
#   재방문 (normalized): 0.071
#   속도 (normalized): 0.635
#   분위기 (normalized): 0.111
# ----------------------------------------
# 가게 ID: 1419339898, 가게 이름: 미담재 양재역점
# 점수 (정규화 전):
#   가성비: 7.419354838709677
#   청결도: 30.64516129032258
#   재방문: 23.548387096774192
#   속도: 0.967741935483871
#   분위기: 7.419354838709677
# 정규화된 점수:
#   가성비 (normalized): 0.441
#   청결도 (normalized): 0.345
#   재방문 (normalized): 0.24
#   속도 (normalized): 0.731
#   분위기 (normalized): 0.332
# ----------------------------------------
# 가게 ID: 36122875, 가게 이름: 설마중
# 점수 (정규화 전):
#   가성비: 9.0
#   청결도: 5.0
#   재방문: 10.0
#   속도: -10.0
#   분위기: 13.0
# 정규화된 점수:
#   가성비 (normalized): 0.461
#   청결도 (normalized): 0.116
#   재방문 (normalized): 0.121
#   속도 (normalized): 0.0
#   분위기 (normalized): 0.479
# ----------------------------------------
# 가게 ID: 1090964067, 가게 이름: 인덕원비빔국수 양재직영점
# 점수 (정규화 전):
#   가성비: -10.714285714285714
#   청결도: -2.142857142857143
#   재방문: -0.7142857142857143
#   속도: 0.7142857142857143
#   분위기: -2.857142857142857
# 정규화된 점수:
#   가성비 (normalized): 0.214
#   청결도 (normalized): 0.052
#   재방문 (normalized): 0.027
#   속도 (normalized): 0.714
#   분위기 (normalized): 0.061
# ----------------------------------------
# 가게 ID: 765084210, 가게 이름: 산내골소갈비살
# 점수 (정규화 전):
#   가성비: 11.258278145695364
#   청결도: 1.3245033112582782
#   재방문: 6.622516556291391
#   속도: 0.6622516556291391
#   분위기: 5.960264900662252
# 정규화된 점수:
#   가성비 (normalized): 0.489
#   청결도 (normalized): 0.083
#   재방문 (normalized): 0.091
#   속도 (normalized): 0.711
#   분위기 (normalized): 0.294
# ----------------------------------------
# 가게 ID: 11680229, 가게 이름: 신선설농탕 도곡점
# 점수 (정규화 전):
#   가성비: -1.6666666666666667
#   청결도: 1.0
#   재방문: 1.6666666666666667
#   속도: -0.33333333333333337
#   분위기: -0.33333333333333337
# 정규화된 점수:
#   가성비 (normalized): 0.327
#   청결도 (normalized): 0.08
#   재방문 (normalized): 0.048
#   속도 (normalized): 0.644
#   분위기 (normalized): 0.127
# ----------------------------------------
# 가게 ID: 1618656208, 가게 이름: 명품생대구탕
# 점수 (정규화 전):
#   가성비: 2.479338842975207
#   청결도: 7.43801652892562
#   재방문: 0.0
#   속도: 0.8264462809917356
#   분위기: 3.3057851239669422
# 정규화된 점수:
#   가성비 (normalized): 0.379
#   청결도 (normalized): 0.138
#   재방문 (normalized): 0.033
#   속도 (normalized): 0.722
#   분위기 (normalized): 0.223
# ----------------------------------------
# 가게 ID: 13160546, 가게 이름: 그램
# 점수 (정규화 전):
#   가성비: 16.666666666666664
#   청결도: -2.083333333333333
#   재방문: 13.88888888888889
#   속도: 2.083333333333333
#   분위기: 14.583333333333334
# 정규화된 점수:
#   가성비 (normalized): 0.557
#   청결도 (normalized): 0.053
#   재방문 (normalized): 0.155
#   속도 (normalized): 0.806
#   분위기 (normalized): 0.521
# ----------------------------------------
# 가게 ID: 1429930181, 가게 이름: 소신
# 점수 (정규화 전):
#   가성비: -3.7037037037037033
#   청결도: 6.790123456790123
#   재방문: 14.19753086419753
#   속도: 1.8518518518518516
#   분위기: 10.493827160493826
# 정규화된 점수:
#   가성비 (normalized): 0.302
#   청결도 (normalized): 0.132
#   재방문 (normalized): 0.158
#   속도 (normalized): 0.79
#   분위기 (normalized): 0.413
# ----------------------------------------
# 가게 ID: 37657812, 가게 이름: 심야식당
# 점수 (정규화 전):
#   가성비: 12.0
#   청결도: -4.0
#   재방문: 0.6666666666666667
#   속도: -4.0
#   분위기: 7.333333333333333
# 정규화된 점수:
#   가성비 (normalized): 0.499
#   청결도 (normalized): 0.036
#   재방문 (normalized): 0.039
#   속도 (normalized): 0.4
#   분위기 (normalized): 0.33
# ----------------------------------------
# 가게 ID: 34521207, 가게 이름: 청정횟집
# 점수 (정규화 전):
#   가성비: -6.896551724137931
#   청결도: 3.4482758620689653
#   재방문: 0.0
#   속도: -1.1494252873563218
#   분위기: -1.1494252873563218
# 정규화된 점수:
#   가성비 (normalized): 0.262
#   청결도 (normalized): 0.102
#   재방문 (normalized): 0.033
#   속도 (normalized): 0.59
#   분위기 (normalized): 0.106
# ----------------------------------------
# 가게 ID: 13150657, 가게 이름: 양재민물매운탕
# 점수 (정규화 전):
#   가성비: 4.444444444444445
#   청결도: -2.2222222222222223
#   재방문: 4.444444444444445
#   속도: -2.2222222222222223
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.404
#   청결도 (normalized): 0.052
#   재방문 (normalized): 0.072
#   속도 (normalized): 0.519
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 13323748, 가게 이름: 박고볼래실내포차
# 점수 (정규화 전):
#   가성비: 3.0864197530864197
#   청결도: -1.2345679012345678
#   재방문: 4.320987654320987
#   속도: -0.6172839506172839
#   분위기: 1.8518518518518516
# 정규화된 점수:
#   가성비 (normalized): 0.387
#   청결도 (normalized): 0.06
#   재방문 (normalized): 0.071
#   속도 (normalized): 0.626
#   분위기 (normalized): 0.185
# ----------------------------------------
# 가게 ID: 1173026949, 가게 이름: 영동회관
# 점수 (정규화 전):
#   가성비: 14.399999999999999
#   청결도: 4.0
#   재방문: 18.4
#   속도: 0.8
#   분위기: 1.2
# 정규화된 점수:
#   가성비 (normalized): 0.529
#   청결도 (normalized): 0.107
#   재방문 (normalized): 0.195
#   속도 (normalized): 0.72
#   분위기 (normalized): 0.168
# ----------------------------------------
# 가게 ID: 1417896057, 가게 이름: 카츠공방 양재점
# 점수 (정규화 전):
#   가성비: 6.25
#   청결도: 8.75
#   재방문: 21.25
#   속도: 2.5
#   분위기: 3.75
# 정규화된 점수:
#   가성비 (normalized): 0.427
#   청결도 (normalized): 0.15
#   재방문 (normalized): 0.22
#   속도 (normalized): 0.833
#   분위기 (normalized): 0.235
# ----------------------------------------
# 가게 ID: 38251615, 가게 이름: 문어세상해천탕 양재점
# 점수 (정규화 전):
#   가성비: 1.574803149606299
#   청결도: 1.574803149606299
#   재방문: 1.968503937007874
#   속도: 0.39370078740157477
#   분위기: -2.3622047244094486
# 정규화된 점수:
#   가성비 (normalized): 0.368
#   청결도 (normalized): 0.085
#   재방문 (normalized): 0.05
#   속도 (normalized): 0.693
#   분위기 (normalized): 0.074
# ----------------------------------------
# 가게 ID: 1123021012, 가게 이름: 호랑이초밥 양재점
# 점수 (정규화 전):
#   가성비: 22.0
#   청결도: 10.8
#   재방문: 12.4
#   속도: 1.6
#   분위기: 3.5999999999999996
# 정규화된 점수:
#   가성비 (normalized): 0.624
#   청결도 (normalized): 0.168
#   재방문 (normalized): 0.142
#   속도 (normalized): 0.773
#   분위기 (normalized): 0.231
# ----------------------------------------
# 가게 ID: 34345158, 가게 이름: 양재정육식당 3호점
# 점수 (정규화 전):
#   가성비: -5.095541401273886
#   청결도: -3.1847133757961785
#   재방문: 1.910828025477707
#   속도: -0.6369426751592357
#   분위기: 1.910828025477707
# 정규화된 점수:
#   가성비 (normalized): 0.284
#   청결도 (normalized): 0.043
#   재방문 (normalized): 0.05
#   속도 (normalized): 0.624
#   분위기 (normalized): 0.187
# ----------------------------------------
# 가게 ID: 37889898, 가게 이름: 콩뿌리콩나물국밥 양재점
# 점수 (정규화 전):
#   가성비: -2.142857142857143
#   청결도: 0.7142857142857143
#   재방문: 0.35714285714285715
#   속도: 1.0714285714285714
#   분위기: -1.4285714285714286
# 정규화된 점수:
#   가성비 (normalized): 0.321
#   청결도 (normalized): 0.078
#   재방문 (normalized): 0.036
#   속도 (normalized): 0.738
#   분위기 (normalized): 0.099
# ----------------------------------------
# 가게 ID: 13376678, 가게 이름: 한솥도시락 양재교육개발원입구점
# 점수 (정규화 전):
#   가성비: 8.47457627118644
#   청결도: 0.423728813559322
#   재방문: 0.847457627118644
#   속도: -0.423728813559322
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.454
#   청결도 (normalized): 0.075
#   재방문 (normalized): 0.04
#   속도 (normalized): 0.638
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1830398009, 가게 이름: 서리풀돈까스
# 점수 (정규화 전):
#   가성비: 5.303030303030303
#   청결도: 0.0
#   재방문: -1.5151515151515151
#   속도: 3.0303030303030303
#   분위기: 2.272727272727273
# 정규화된 점수:
#   가성비 (normalized): 0.415
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.02
#   속도 (normalized): 0.869
#   분위기 (normalized): 0.196
# ----------------------------------------
# 가게 ID: 37307613, 가게 이름: 양재오제섞어 양재본점
# 점수 (정규화 전):
#   가성비: -11.785714285714285
#   청결도: 0.7142857142857143
#   재방문: 1.7857142857142856
#   속도: -1.0714285714285714
#   분위기: -0.35714285714285715
# 정규화된 점수:
#   가성비 (normalized): 0.2
#   청결도 (normalized): 0.078
#   재방문 (normalized): 0.049
#   속도 (normalized): 0.595
#   분위기 (normalized): 0.127
# ----------------------------------------
# 가게 ID: 1927679596, 가게 이름: 에베레스트 양재점
# 점수 (정규화 전):
#   가성비: 10.689655172413794
#   청결도: 3.4482758620689653
#   재방문: 24.482758620689655
#   속도: 1.0344827586206897
#   분위기: 3.793103448275862
# 정규화된 점수:
#   가성비 (normalized): 0.482
#   청결도 (normalized): 0.102
#   재방문 (normalized): 0.248
#   속도 (normalized): 0.736
#   분위기 (normalized): 0.236
# ----------------------------------------
# 가게 ID: 1886378828, 가게 이름: 곱창왕김형제 양재역본점
# 점수 (정규화 전):
#   가성비: -10.0
#   청결도: 2.0
#   재방문: 13.333333333333334
#   속도: -0.6666666666666667
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.223
#   청결도 (normalized): 0.089
#   재방문 (normalized): 0.15
#   속도 (normalized): 0.622
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1891561259, 가게 이름: 월계랑
# 점수 (정규화 전):
#   가성비: 25.555555555555554
#   청결도: 14.444444444444443
#   재방문: 26.666666666666668
#   속도: -3.3333333333333335
#   분위기: 6.666666666666667
# 정규화된 점수:
#   가성비 (normalized): 0.669
#   청결도 (normalized): 0.2
#   재방문 (normalized): 0.267
#   속도 (normalized): 0.444
#   분위기 (normalized): 0.312
# ----------------------------------------
# 가게 ID: 1278613093, 가게 이름: 지세포세꼬시
# 점수 (정규화 전):
#   가성비: 0.0
#   청결도: -2.459016393442623
#   재방문: 3.278688524590164
#   속도: -2.459016393442623
#   분위기: -2.459016393442623
# 정규화된 점수:
#   가성비 (normalized): 0.348
#   청결도 (normalized): 0.049
#   재방문 (normalized): 0.062
#   속도 (normalized): 0.503
#   분위기 (normalized): 0.071
# ----------------------------------------
# 가게 ID: 13348519, 가게 이름: 타이쇼
# 점수 (정규화 전):
#   가성비: 6.451612903225806
#   청결도: 4.516129032258064
#   재방문: 31.93548387096774
#   속도: 0.0
#   분위기: 20.64516129032258
# 정규화된 점수:
#   가성비 (normalized): 0.429
#   청결도 (normalized): 0.112
#   재방문 (normalized): 0.314
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.681
# ----------------------------------------
# 가게 ID: 1567180996, 가게 이름: 에그드랍 양재역점
# 점수 (정규화 전):
#   가성비: 7.5
#   청결도: 5.0
#   재방문: -3.75
#   속도: -5.0
#   분위기: -1.25
# 정규화된 점수:
#   가성비 (normalized): 0.442
#   청결도 (normalized): 0.116
#   재방문 (normalized): 0.0
#   속도 (normalized): 0.333
#   분위기 (normalized): 0.103
# ----------------------------------------
# 가게 ID: 31186755, 가게 이름: 아리노마마
# 점수 (정규화 전):
#   가성비: -1.9157088122605364
#   청결도: -1.1494252873563218
#   재방문: 5.747126436781609
#   속도: -2.681992337164751
#   분위기: 13.793103448275861
# 정규화된 점수:
#   가성비 (normalized): 0.324
#   청결도 (normalized): 0.061
#   재방문 (normalized): 0.083
#   속도 (normalized): 0.488
#   분위기 (normalized): 0.5
# ----------------------------------------
# 가게 ID: 1807443956, 가게 이름: 양재역 조개맛집
# 점수 (정규화 전):
#   가성비: 7.5
#   청결도: -1.25
#   재방문: 11.25
#   속도: 0.0
#   분위기: 7.5
# 정규화된 점수:
#   가성비 (normalized): 0.442
#   청결도 (normalized): 0.06
#   재방문 (normalized): 0.132
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.334
# ----------------------------------------
# 가게 ID: 1944962798, 가게 이름: 이가네양꼬치 양재역직영점
# 점수 (정규화 전):
#   가성비: -21.11111111111111
#   청결도: 2.2222222222222223
#   재방문: 5.185185185185185
#   속도: -1.1111111111111112
#   분위기: 1.8518518518518516
# 정규화된 점수:
#   가성비 (normalized): 0.084
#   청결도 (normalized): 0.091
#   재방문 (normalized): 0.079
#   속도 (normalized): 0.593
#   분위기 (normalized): 0.185
# ----------------------------------------
# 가게 ID: 31600260, 가게 이름: 잰부닥
# 점수 (정규화 전):
#   가성비: -14.457831325301203
#   청결도: -1.2048192771084338
#   재방문: 1.6064257028112447
#   속도: -3.2128514056224895
#   분위기: -3.614457831325301
# 정규화된 점수:
#   가성비 (normalized): 0.167
#   청결도 (normalized): 0.061
#   재방문 (normalized): 0.047
#   속도 (normalized): 0.452
#   분위기 (normalized): 0.041
# ----------------------------------------
# 가게 ID: 234208683, 가게 이름: 양인환대
# 점수 (정규화 전):
#   가성비: -16.014234875444842
#   청결도: 2.491103202846975
#   재방문: 2.135231316725979
#   속도: -3.202846975088968
#   분위기: 10.320284697508896
# 정규화된 점수:
#   가성비 (normalized): 0.147
#   청결도 (normalized): 0.094
#   재방문 (normalized): 0.052
#   속도 (normalized): 0.453
#   분위기 (normalized): 0.409
# ----------------------------------------
# 가게 ID: 38474259, 가게 이름: 오향절면 양재본점
# 점수 (정규화 전):
#   가성비: 7.82608695652174
#   청결도: 6.521739130434782
#   재방문: 7.82608695652174
#   속도: 1.3043478260869565
#   분위기: -1.7391304347826086
# 정규화된 점수:
#   가성비 (normalized): 0.446
#   청결도 (normalized): 0.13
#   재방문 (normalized): 0.102
#   속도 (normalized): 0.754
#   분위기 (normalized): 0.09
# ----------------------------------------
# 가게 ID: 1672141709, 가게 이름: 육즙관리소 양재역점
# 점수 (정규화 전):
#   가성비: 1.25
#   청결도: 8.125
#   재방문: 19.375
#   속도: -1.5625
#   분위기: 10.9375
# 정규화된 점수:
#   가성비 (normalized): 0.364
#   청결도 (normalized): 0.144
#   재방문 (normalized): 0.203
#   속도 (normalized): 0.562
#   분위기 (normalized): 0.425
# ----------------------------------------
# 가게 ID: 1658172503, 가게 이름: 닭곰탱이 양재역점
# 점수 (정규화 전):
#   가성비: 22.5
#   청결도: 0.0
#   재방문: 2.5
#   속도: -1.25
#   분위기: 7.5
# 정규화된 점수:
#   가성비 (normalized): 0.63
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.055
#   속도 (normalized): 0.583
#   분위기 (normalized): 0.334
# ----------------------------------------
# 가게 ID: 1037966057, 가게 이름: 피끄니크
# 점수 (정규화 전):
#   가성비: 9.333333333333334
#   청결도: 5.0
#   재방문: 7.333333333333333
#   속도: 0.6666666666666667
#   분위기: 5.333333333333334
# 정규화된 점수:
#   가성비 (normalized): 0.465
#   청결도 (normalized): 0.116
#   재방문 (normalized): 0.097
#   속도 (normalized): 0.711
#   분위기 (normalized): 0.277
# ----------------------------------------
# 가게 ID: 1786476142, 가게 이름: 로마옥 도곡
# 점수 (정규화 전):
#   가성비: -18.181818181818183
#   청결도: 3.6363636363636362
#   재방문: 12.727272727272727
#   속도: -3.6363636363636362
#   분위기: 32.72727272727273
# 정규화된 점수:
#   가성비 (normalized): 0.12
#   청결도 (normalized): 0.104
#   재방문 (normalized): 0.145
#   속도 (normalized): 0.424
#   분위기 (normalized): 1.0
# ----------------------------------------
# 가게 ID: 36538658, 가게 이름: 니혼슈바 슈토
# 점수 (정규화 전):
#   가성비: 10.476190476190476
#   청결도: 1.4285714285714286
#   재방문: 5.714285714285714
#   속도: -6.190476190476191
#   분위기: 8.095238095238095
# 정규화된 점수:
#   가성비 (normalized): 0.48
#   청결도 (normalized): 0.084
#   재방문 (normalized): 0.083
#   속도 (normalized): 0.254
#   분위기 (normalized): 0.35
# ----------------------------------------
# 가게 ID: 20897027, 가게 이름: 작은공간
# 점수 (정규화 전):
#   가성비: 0.7407407407407408
#   청결도: -1.1111111111111112
#   재방문: 3.7037037037037033
#   속도: -0.3703703703703704
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.357
#   청결도 (normalized): 0.062
#   재방문 (normalized): 0.066
#   속도 (normalized): 0.642
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 37615410, 가게 이름: 신전떡볶이 도곡점
# 점수 (정규화 전):
#   가성비: 1.809954751131222
#   청결도: -0.4524886877828055
#   재방문: 3.619909502262444
#   속도: 0.0
#   분위기: -0.4524886877828055
# 정규화된 점수:
#   가성비 (normalized): 0.371
#   청결도 (normalized): 0.067
#   재방문 (normalized): 0.065
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.124
# ----------------------------------------
# 가게 ID: 35155951, 가게 이름: 국미당
# 점수 (정규화 전):
#   가성비: -11.37123745819398
#   청결도: -1.3377926421404682
#   재방문: 1.6722408026755853
#   속도: -4.013377926421405
#   분위기: -1.3377926421404682
# 정규화된 점수:
#   가성비 (normalized): 0.206
#   청결도 (normalized): 0.059
#   재방문 (normalized): 0.048
#   속도 (normalized): 0.399
#   분위기 (normalized): 0.101
# ----------------------------------------
# 가게 ID: 1034622849, 가게 이름: 국고집
# 점수 (정규화 전):
#   가성비: 35.483870967741936
#   청결도: 6.774193548387098
#   재방문: 16.7741935483871
#   속도: 0.967741935483871
#   분위기: -5.161290322580645
# 정규화된 점수:
#   가성비 (normalized): 0.793
#   청결도 (normalized): 0.132
#   재방문 (normalized): 0.18
#   속도 (normalized): 0.731
#   분위기 (normalized): 0.0
# ----------------------------------------
# 가게 ID: 30922907, 가게 이름: 스파게티스토리
# 점수 (정규화 전):
#   가성비: 3.6363636363636362
#   청결도: -6.363636363636363
#   재방문: 3.6363636363636362
#   속도: 1.8181818181818181
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.394
#   청결도 (normalized): 0.015
#   재방문 (normalized): 0.065
#   속도 (normalized): 0.788
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 20601502, 가게 이름: 그린네 은쟁반
# 점수 (정규화 전):
#   가성비: -2.0
#   청결도: -1.0
#   재방문: 1.0
#   속도: -2.0
#   분위기: -1.0
# 정규화된 점수:
#   가성비 (normalized): 0.323
#   청결도 (normalized): 0.062
#   재방문 (normalized): 0.042
#   속도 (normalized): 0.533
#   분위기 (normalized): 0.11
# ----------------------------------------
# 가게 ID: 1889974700, 가게 이름: 마라홀릭 마라탕 양재역점
# 점수 (정규화 전):
#   가성비: 6.666666666666667
#   청결도: 7.142857142857142
#   재방문: 23.809523809523807
#   속도: 2.380952380952381
#   분위기: 1.4285714285714286
# 정규화된 점수:
#   가성비 (normalized): 0.432
#   청결도 (normalized): 0.135
#   재방문 (normalized): 0.242
#   속도 (normalized): 0.825
#   분위기 (normalized): 0.174
# ----------------------------------------
# 가게 ID: 1672897084, 가게 이름: 본죽&비빔밥cafe 양재은광여고점
# 점수 (정규화 전):
#   가성비: 2.258064516129032
#   청결도: 4.838709677419355
#   재방문: 2.258064516129032
#   속도: -0.967741935483871
#   분위기: 0.967741935483871
# 정규화된 점수:
#   가성비 (normalized): 0.376
#   청결도 (normalized): 0.115
#   재방문 (normalized): 0.053
#   속도 (normalized): 0.602
#   분위기 (normalized): 0.162
# ----------------------------------------
# 가게 ID: 35307516, 가게 이름: 제레미버거
# 점수 (정규화 전):
#   가성비: -2.2222222222222223
#   청결도: 1.6666666666666667
#   재방문: 2.2222222222222223
#   속도: -1.1111111111111112
#   분위기: -1.1111111111111112
# 정규화된 점수:
#   가성비 (normalized): 0.32
#   청결도 (normalized): 0.086
#   재방문 (normalized): 0.053
#   속도 (normalized): 0.593
#   분위기 (normalized): 0.107
# ----------------------------------------
# 가게 ID: 34098856, 가게 이름: 얌얌 양재점
# 점수 (정규화 전):
#   가성비: 1.6666666666666667
#   청결도: -1.3333333333333335
#   재방문: 4.0
#   속도: 2.3333333333333335
#   분위기: -0.33333333333333337
# 정규화된 점수:
#   가성비 (normalized): 0.369
#   청결도 (normalized): 0.06
#   재방문 (normalized): 0.068
#   속도 (normalized): 0.822
#   분위기 (normalized): 0.127
# ----------------------------------------
# 가게 ID: 12950069, 가게 이름: 디오디아2.0
# 점수 (정규화 전):
#   가성비: 14.827586206896552
#   청결도: 8.620689655172415
#   재방문: 20.0
#   속도: -2.7586206896551726
#   분위기: 15.862068965517242
# 정규화된 점수:
#   가성비 (normalized): 0.534
#   청결도 (normalized): 0.148
#   재방문 (normalized): 0.209
#   속도 (normalized): 0.483
#   분위기 (normalized): 0.555
# ----------------------------------------
# 가게 ID: 1664070278, 가게 이름: 용짜장 양재점
# 점수 (정규화 전):
#   가성비: 1.4184397163120568
#   청결도: 0.0
#   재방문: 1.4184397163120568
#   속도: 0.7092198581560284
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.366
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.045
#   속도 (normalized): 0.714
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1154400830, 가게 이름: 깐부치킨 양재역점
# 점수 (정규화 전):
#   가성비: -4.424778761061947
#   청결도: -1.3274336283185841
#   재방문: 0.4424778761061947
#   속도: -1.7699115044247788
#   분위기: 2.6548672566371683
# 정규화된 점수:
#   가성비 (normalized): 0.293
#   청결도 (normalized): 0.06
#   재방문 (normalized): 0.037
#   속도 (normalized): 0.549
#   분위기 (normalized): 0.206
# ----------------------------------------
# 가게 ID: 33459979, 가게 이름: 치킨처럼 양재역점
# 점수 (정규화 전):
#   가성비: 2.631578947368421
#   청결도: 0.6578947368421052
#   재방문: -0.6578947368421052
#   속도: -0.6578947368421052
#   분위기: -1.9736842105263157
# 정규화된 점수:
#   가성비 (normalized): 0.381
#   청결도 (normalized): 0.077
#   재방문 (normalized): 0.027
#   속도 (normalized): 0.623
#   분위기 (normalized): 0.084
# ----------------------------------------
# 가게 ID: 32699962, 가게 이름: 장수정육식당
# 점수 (정규화 전):
#   가성비: 8.88888888888889
#   청결도: -1.1111111111111112
#   재방문: 1.1111111111111112
#   속도: 0.0
#   분위기: 2.2222222222222223
# 정규화된 점수:
#   가성비 (normalized): 0.46
#   청결도 (normalized): 0.062
#   재방문 (normalized): 0.043
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.195
# ----------------------------------------
# 가게 ID: 1069491314, 가게 이름: 뎁짜이 양재역점
# 점수 (정규화 전):
#   가성비: 11.875
#   청결도: 11.875
#   재방문: 15.0
#   속도: -0.625
#   분위기: 4.375
# 정규화된 점수:
#   가성비 (normalized): 0.497
#   청결도 (normalized): 0.177
#   재방문 (normalized): 0.165
#   속도 (normalized): 0.625
#   분위기 (normalized): 0.252
# ----------------------------------------
# 가게 ID: 19882315, 가게 이름: 자인뭉티기
# 점수 (정규화 전):
#   가성비: -5.384615384615385
#   청결도: 1.5384615384615385
#   재방문: 7.307692307692308
#   속도: 1.153846153846154
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.281
#   청결도 (normalized): 0.085
#   재방문 (normalized): 0.097
#   속도 (normalized): 0.744
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1081786133, 가게 이름: 훅트포케 양재점
# 점수 (정규화 전):
#   가성비: 7.916666666666666
#   청결도: 10.0
#   재방문: 15.0
#   속도: -0.8333333333333334
#   분위기: 7.916666666666666
# 정규화된 점수:
#   가성비 (normalized): 0.447
#   청결도 (normalized): 0.161
#   재방문 (normalized): 0.165
#   속도 (normalized): 0.611
#   분위기 (normalized): 0.345
# ----------------------------------------
# 가게 ID: 1625687301, 가게 이름: 힐튼가든인 서울강남 가든 비스트로
# 점수 (정규화 전):
#   가성비: 7.931034482758621
#   청결도: 11.379310344827587
#   재방문: 5.862068965517241
#   속도: -5.172413793103448
#   분위기: 13.10344827586207
# 정규화된 점수:
#   가성비 (normalized): 0.448
#   청결도 (normalized): 0.173
#   재방문 (normalized): 0.085
#   속도 (normalized): 0.322
#   분위기 (normalized): 0.482
# ----------------------------------------
# 가게 ID: 38643869, 가게 이름: 양지수제샌드위치
# 점수 (정규화 전):
#   가성비: -18.181818181818183
#   청결도: 2.0202020202020203
#   재방문: 0.0
#   속도: -1.0101010101010102
#   분위기: 6.0606060606060606
# 정규화된 점수:
#   가성비 (normalized): 0.12
#   청결도 (normalized): 0.089
#   재방문 (normalized): 0.033
#   속도 (normalized): 0.599
#   분위기 (normalized): 0.296
# ----------------------------------------
# 가게 ID: 36868411, 가게 이름: 순남시래기 양재점
# 점수 (정규화 전):
#   가성비: 4.838709677419355
#   청결도: 1.935483870967742
#   재방문: 2.258064516129032
#   속도: 1.6129032258064515
#   분위기: -0.3225806451612903
# 정규화된 점수:
#   가성비 (normalized): 0.409
#   청결도 (normalized): 0.089
#   재방문 (normalized): 0.053
#   속도 (normalized): 0.774
#   분위기 (normalized): 0.128
# ----------------------------------------
# 가게 ID: 20874669, 가게 이름: 황재벌 본점
# 점수 (정규화 전):
#   가성비: -8.0
#   청결도: -2.666666666666667
#   재방문: 3.6666666666666665
#   속도: -1.6666666666666667
#   분위기: -1.3333333333333335
# 정규화된 점수:
#   가성비 (normalized): 0.248
#   청결도 (normalized): 0.048
#   재방문 (normalized): 0.065
#   속도 (normalized): 0.556
#   분위기 (normalized): 0.101
# ----------------------------------------
# 가게 ID: 13157782, 가게 이름: 늘봄족발보쌈
# 점수 (정규화 전):
#   가성비: 19.565217391304348
#   청결도: 2.1739130434782608
#   재방문: 2.1739130434782608
#   속도: 1.0869565217391304
#   분위기: -3.260869565217391
# 정규화된 점수:
#   가성비 (normalized): 0.593
#   청결도 (normalized): 0.091
#   재방문 (normalized): 0.052
#   속도 (normalized): 0.739
#   분위기 (normalized): 0.05
# ----------------------------------------
# 가게 ID: 1192671730, 가게 이름: 오부찌 양재점
# 점수 (정규화 전):
#   가성비: 9.961685823754788
#   청결도: 3.065134099616858
#   재방문: 4.21455938697318
#   속도: 1.9157088122605364
#   분위기: 0.38314176245210724
# 정규화된 점수:
#   가성비 (normalized): 0.473
#   청결도 (normalized): 0.099
#   재방문 (normalized): 0.07
#   속도 (normalized): 0.794
#   분위기 (normalized): 0.146
# ----------------------------------------
# 가게 ID: 38591616, 가게 이름: 고양이부엌 양재구청점
# 점수 (정규화 전):
#   가성비: 8.169934640522875
#   청결도: -0.6535947712418301
#   재방문: -0.6535947712418301
#   속도: -1.6339869281045754
#   분위기: 3.594771241830065
# 정규화된 점수:
#   가성비 (normalized): 0.451
#   청결도 (normalized): 0.066
#   재방문 (normalized): 0.027
#   속도 (normalized): 0.558
#   분위기 (normalized): 0.231
# ----------------------------------------
# 가게 ID: 1320179295, 가게 이름: 크라이치즈버거 양재역점
# 점수 (정규화 전):
#   가성비: -14.166666666666666
#   청결도: 7.5
#   재방문: -0.8333333333333334
#   속도: -0.8333333333333334
#   분위기: 2.5
# 정규화된 점수:
#   가성비 (normalized): 0.171
#   청결도 (normalized): 0.138
#   재방문 (normalized): 0.026
#   속도 (normalized): 0.611
#   분위기 (normalized): 0.202
# ----------------------------------------
# 가게 ID: 11861500, 가게 이름: 전주옛날집
# 점수 (정규화 전):
#   가성비: 1.910828025477707
#   청결도: 0.6369426751592357
#   재방문: -1.2738853503184715
#   속도: 0.6369426751592357
#   분위기: -2.547770700636943
# 정규화된 점수:
#   가성비 (normalized): 0.372
#   청결도 (normalized): 0.077
#   재방문 (normalized): 0.022
#   속도 (normalized): 0.709
#   분위기 (normalized): 0.069
# ----------------------------------------
# 가게 ID: 1078767514, 가게 이름: 서초목살
# 점수 (정규화 전):
#   가성비: 9.230769230769232
#   청결도: 2.307692307692308
#   재방문: 33.07692307692307
#   속도: 3.8461538461538463
#   분위기: -1.5384615384615385
# 정규화된 점수:
#   가성비 (normalized): 0.464
#   청결도 (normalized): 0.092
#   재방문 (normalized): 0.324
#   속도 (normalized): 0.923
#   분위기 (normalized): 0.096
# ----------------------------------------
# 가게 ID: 31134978, 가게 이름: 본도시락 양재점
# 점수 (정규화 전):
#   가성비: 3.4482758620689653
#   청결도: 1.3793103448275863
#   재방문: 2.0689655172413794
#   속도: 2.7586206896551726
#   분위기: -0.6896551724137931
# 정규화된 점수:
#   가성비 (normalized): 0.391
#   청결도 (normalized): 0.084
#   재방문 (normalized): 0.051
#   속도 (normalized): 0.851
#   분위기 (normalized): 0.118
# ----------------------------------------
# 가게 ID: 18771333, 가게 이름: 진스시
# 점수 (정규화 전):
#   가성비: 4.193548387096775
#   청결도: 12.580645161290322
#   재방문: 3.5483870967741935
#   속도: -1.6129032258064515
#   분위기: 12.580645161290322
# 정규화된 점수:
#   가성비 (normalized): 0.401
#   청결도 (normalized): 0.184
#   재방문 (normalized): 0.064
#   속도 (normalized): 0.559
#   분위기 (normalized): 0.468
# ----------------------------------------
# 가게 ID: 37997726, 가게 이름: 봉피양 양재점
# 점수 (정규화 전):
#   가성비: -12.195121951219512
#   청결도: 0.0
#   재방문: -0.6968641114982579
#   속도: -7.317073170731707
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.195
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.027
#   속도 (normalized): 0.179
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 37236849, 가게 이름: 돼지연구소 양재직영점
# 점수 (정규화 전):
#   가성비: -4.680851063829787
#   청결도: 2.553191489361702
#   재방문: 8.51063829787234
#   속도: 0.0
#   분위기: 0.425531914893617
# 정규화된 점수:
#   가성비 (normalized): 0.29
#   청결도 (normalized): 0.094
#   재방문 (normalized): 0.108
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.147
# ----------------------------------------
# 가게 ID: 1268565080, 가게 이름: 솥두껍 양재본점
# 점수 (정규화 전):
#   가성비: 20.0
#   청결도: 3.225806451612903
#   재방문: 25.806451612903224
#   속도: -1.935483870967742
#   분위기: 0.3225806451612903
# 정규화된 점수:
#   가성비 (normalized): 0.599
#   청결도 (normalized): 0.1
#   재방문 (normalized): 0.26
#   속도 (normalized): 0.538
#   분위기 (normalized): 0.145
# ----------------------------------------
# 가게 ID: 37902481, 가게 이름: 깡돈
# 점수 (정규화 전):
#   가성비: 11.71875
#   청결도: -0.78125
#   재방문: 3.90625
#   속도: 2.34375
#   분위기: 0.78125
# 정규화된 점수:
#   가성비 (normalized): 0.495
#   청결도 (normalized): 0.064
#   재방문 (normalized): 0.067
#   속도 (normalized): 0.823
#   분위기 (normalized): 0.157
# ----------------------------------------
# 가게 ID: 32821881, 가게 이름: 토봉추어탕
# 점수 (정규화 전):
#   가성비: -0.3225806451612903
#   청결도: 1.935483870967742
#   재방문: 3.870967741935484
#   속도: 0.3225806451612903
#   분위기: 1.2903225806451613
# 정규화된 점수:
#   가성비 (normalized): 0.344
#   청결도 (normalized): 0.089
#   재방문 (normalized): 0.067
#   속도 (normalized): 0.688
#   분위기 (normalized): 0.17
# ----------------------------------------
# 가게 ID: 1044461398, 가게 이름: 우대포 양재점
# 점수 (정규화 전):
#   가성비: 34.516129032258064
#   청결도: 14.516129032258066
#   재방문: 25.161290322580644
#   속도: 1.2903225806451613
#   분위기: 3.5483870967741935
# 정규화된 점수:
#   가성비 (normalized): 0.781
#   청결도 (normalized): 0.201
#   재방문 (normalized): 0.254
#   속도 (normalized): 0.753
#   분위기 (normalized): 0.23
# ----------------------------------------
# 가게 ID: 11627634, 가게 이름: 버드나무집 서초동본점
# 점수 (정규화 전):
#   가성비: -14.705882352941178
#   청결도: 1.7647058823529411
#   재방문: 1.7647058823529411
#   속도: -0.5882352941176471
#   분위기: -2.941176470588235
# 정규화된 점수:
#   가성비 (normalized): 0.164
#   청결도 (normalized): 0.087
#   재방문 (normalized): 0.048
#   속도 (normalized): 0.627
#   분위기 (normalized): 0.059
# ----------------------------------------
# 가게 ID: 18779141, 가게 이름: 듬북담북 뱅뱅점
# 점수 (정규화 전):
#   가성비: 1.9607843137254901
#   청결도: 0.9803921568627451
#   재방문: 2.941176470588235
#   속도: 0.49019607843137253
#   분위기: -1.9607843137254901
# 정규화된 점수:
#   가성비 (normalized): 0.373
#   청결도 (normalized): 0.08
#   재방문 (normalized): 0.059
#   속도 (normalized): 0.699
#   분위기 (normalized): 0.084
# ----------------------------------------
# 가게 ID: 98898756, 가게 이름: 양재정육식당 역삼뱅뱅점
# 점수 (정규화 전):
#   가성비: 4.56140350877193
#   청결도: 0.3508771929824561
#   재방문: 3.1578947368421053
#   속도: -0.3508771929824561
#   분위기: -0.7017543859649122
# 정규화된 점수:
#   가성비 (normalized): 0.405
#   청결도 (normalized): 0.075
#   재방문 (normalized): 0.061
#   속도 (normalized): 0.643
#   분위기 (normalized): 0.118
# ----------------------------------------
# 가게 ID: 13150366, 가게 이름: 참설농탕 서초점
# 점수 (정규화 전):
#   가성비: -15.862068965517242
#   청결도: -0.6896551724137931
#   재방문: 3.4482758620689653
#   속도: 0.0
#   분위기: -0.6896551724137931
# 정규화된 점수:
#   가성비 (normalized): 0.149
#   청결도 (normalized): 0.065
#   재방문 (normalized): 0.063
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.118
# ----------------------------------------
# 가게 ID: 1550997885, 가게 이름: 부안애서 서초점
# 점수 (정규화 전):
#   가성비: 15.161290322580644
#   청결도: 14.516129032258066
#   재방문: 12.258064516129032
#   속도: 0.967741935483871
#   분위기: 6.129032258064516
# 정규화된 점수:
#   가성비 (normalized): 0.538
#   청결도 (normalized): 0.201
#   재방문 (normalized): 0.141
#   속도 (normalized): 0.731
#   분위기 (normalized): 0.298
# ----------------------------------------
# 가게 ID: 34582729, 가게 이름: 담소소사골순대육개장 서초점
# 점수 (정규화 전):
#   가성비: 4.333333333333334
#   청결도: 1.6666666666666667
#   재방문: 0.33333333333333337
#   속도: -0.33333333333333337
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.403
#   청결도 (normalized): 0.086
#   재방문 (normalized): 0.036
#   속도 (normalized): 0.644
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 18361460, 가게 이름: 광양참숯불고기
# 점수 (정규화 전):
#   가성비: -6.282722513089005
#   청결도: 3.664921465968586
#   재방문: 2.094240837696335
#   속도: -1.0471204188481675
#   분위기: -0.5235602094240838
# 정규화된 점수:
#   가성비 (normalized): 0.269
#   청결도 (normalized): 0.104
#   재방문 (normalized): 0.051
#   속도 (normalized): 0.597
#   분위기 (normalized): 0.122
# ----------------------------------------
# 가게 ID: 1532111915, 가게 이름: 푸라닭 서초2동점
# 점수 (정규화 전):
#   가성비: 0.0
#   청결도: 2.7777777777777777
#   재방문: 3.3333333333333335
#   속도: 1.6666666666666667
#   분위기: -2.7777777777777777
# 정규화된 점수:
#   가성비 (normalized): 0.348
#   청결도 (normalized): 0.096
#   재방문 (normalized): 0.062
#   속도 (normalized): 0.778
#   분위기 (normalized): 0.063
# ----------------------------------------
# 가게 ID: 1925656389, 가게 이름: 피넘타이
# 점수 (정규화 전):
#   가성비: 9.166666666666666
#   청결도: 10.833333333333334
#   재방문: 17.5
#   속도: 0.8333333333333334
#   분위기: 14.166666666666666
# 정규화된 점수:
#   가성비 (normalized): 0.463
#   청결도 (normalized): 0.168
#   재방문 (normalized): 0.187
#   속도 (normalized): 0.722
#   분위기 (normalized): 0.51
# ----------------------------------------
# 가게 ID: 20083769, 가게 이름: 전사랑 서초본점
# 점수 (정규화 전):
#   가성비: 8.484848484848486
#   청결도: 7.878787878787878
#   재방문: 12.727272727272727
#   속도: -3.0303030303030303
#   분위기: 4.242424242424243
# 정규화된 점수:
#   가성비 (normalized): 0.455
#   청결도 (normalized): 0.142
#   재방문 (normalized): 0.145
#   속도 (normalized): 0.465
#   분위기 (normalized): 0.248
# ----------------------------------------
# 가게 ID: 1137666363, 가게 이름: 옥된장 양재점
# 점수 (정규화 전):
#   가성비: 11.818181818181818
#   청결도: 9.090909090909092
#   재방문: 10.0
#   속도: 1.8181818181818181
#   분위기: 7.2727272727272725
# 정규화된 점수:
#   가성비 (normalized): 0.496
#   청결도 (normalized): 0.153
#   재방문 (normalized): 0.121
#   속도 (normalized): 0.788
#   분위기 (normalized): 0.328
# ----------------------------------------
# 가게 ID: 1553486347, 가게 이름: 마라두목 양재점
# 점수 (정규화 전):
#   가성비: 11.428571428571429
#   청결도: 17.857142857142858
#   재방문: 15.0
#   속도: 4.285714285714286
#   분위기: 9.285714285714286
# 정규화된 점수:
#   가성비 (normalized): 0.491
#   청결도 (normalized): 0.231
#   재방문 (normalized): 0.165
#   속도 (normalized): 0.952
#   분위기 (normalized): 0.381
# ----------------------------------------
# 가게 ID: 1688755338, 가게 이름: 백소정 양재역점
# 점수 (정규화 전):
#   가성비: 17.142857142857142
#   청결도: 14.642857142857144
#   재방문: 12.5
#   속도: -0.7142857142857143
#   분위기: 1.7857142857142856
# 정규화된 점수:
#   가성비 (normalized): 0.563
#   청결도 (normalized): 0.202
#   재방문 (normalized): 0.143
#   속도 (normalized): 0.619
#   분위기 (normalized): 0.183
# ----------------------------------------
# 가게 ID: 1516711006, 가게 이름: 불로삼계백숙
# 점수 (정규화 전):
#   가성비: 11.042944785276074
#   청결도: 2.4539877300613497
#   재방문: 4.294478527607362
#   속도: -1.2269938650306749
#   분위기: 2.4539877300613497
# 정규화된 점수:
#   가성비 (normalized): 0.487
#   청결도 (normalized): 0.093
#   재방문 (normalized): 0.071
#   속도 (normalized): 0.585
#   분위기 (normalized): 0.201
# ----------------------------------------
# 가게 ID: 1932467805, 가게 이름: 보글이 생태탕왕코다리 양재역점
# 점수 (정규화 전):
#   가성비: 35.714285714285715
#   청결도: 8.214285714285714
#   재방문: 10.0
#   속도: -0.35714285714285715
#   분위기: 2.5
# 정규화된 점수:
#   가성비 (normalized): 0.796
#   청결도 (normalized): 0.145
#   재방문 (normalized): 0.121
#   속도 (normalized): 0.643
#   분위기 (normalized): 0.202
# ----------------------------------------
# 가게 ID: 1698302178, 가게 이름: 도화
# 점수 (정규화 전):
#   가성비: 5.782312925170068
#   청결도: 4.421768707482993
#   재방문: 4.761904761904762
#   속도: -0.6802721088435374
#   분위기: 3.061224489795918
# 정규화된 점수:
#   가성비 (normalized): 0.421
#   청결도 (normalized): 0.111
#   재방문 (normalized): 0.075
#   속도 (normalized): 0.621
#   분위기 (normalized): 0.217
# ----------------------------------------
# 가게 ID: 1113983640, 가게 이름: 탐라순대국감자탕 양재역직영점
# 점수 (정규화 전):
#   가성비: 52.0
#   청결도: 104.0
#   재방문: 110.00000000000001
#   속도: 2.0
#   분위기: 12.0
# 정규화된 점수:
#   가성비 (normalized): 1.0
#   청결도 (normalized): 1.0
#   재방문 (normalized): 1.0
#   속도 (normalized): 0.8
#   분위기 (normalized): 0.453
# ----------------------------------------
# 가게 ID: 1751873950, 가게 이름: 양재순대
# 점수 (정규화 전):
#   가성비: 1.0714285714285714
#   청결도: -0.35714285714285715
#   재방문: 0.35714285714285715
#   속도: -1.0714285714285714
#   분위기: 1.0714285714285714
# 정규화된 점수:
#   가성비 (normalized): 0.362
#   청결도 (normalized): 0.068
#   재방문 (normalized): 0.036
#   속도 (normalized): 0.595
#   분위기 (normalized): 0.165
# ----------------------------------------
# 가게 ID: 18307489, 가게 이름: 어부참치
# 점수 (정규화 전):
#   가성비: -7.627118644067797
#   청결도: 2.5423728813559325
#   재방문: 2.5423728813559325
#   속도: -0.847457627118644
#   분위기: 0.847457627118644
# 정규화된 점수:
#   가성비 (normalized): 0.253
#   청결도 (normalized): 0.094
#   재방문 (normalized): 0.055
#   속도 (normalized): 0.61
#   분위기 (normalized): 0.159
# ----------------------------------------
# 가게 ID: 1941253545, 가게 이름: Poke all day 포케&샐러드 양재점
# 점수 (정규화 전):
#   가성비: 2.5089605734767026
#   청결도: 18.63799283154122
#   재방문: 13.620071684587815
#   속도: 2.867383512544803
#   분위기: 4.301075268817205
# 정규화된 점수:
#   가성비 (normalized): 0.38
#   청결도 (normalized): 0.238
#   재방문 (normalized): 0.153
#   속도 (normalized): 0.858
#   분위기 (normalized): 0.25
# ----------------------------------------
# 가게 ID: 1827894067, 가게 이름: 명가무안뻘낙지
# 점수 (정규화 전):
#   가성비: -17.0
#   청결도: -8.0
#   재방문: 4.0
#   속도: -4.0
#   분위기: 1.0
# 정규화된 점수:
#   가성비 (normalized): 0.135
#   청결도 (normalized): 0.0
#   재방문 (normalized): 0.068
#   속도 (normalized): 0.4
#   분위기 (normalized): 0.163
# ----------------------------------------
# 가게 ID: 13150440, 가게 이름: 콩나루콩나물국밥 직영점
# 점수 (정규화 전):
#   가성비: 2.2058823529411766
#   청결도: -0.7352941176470588
#   재방문: 3.6764705882352944
#   속도: 0.7352941176470588
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.376
#   청결도 (normalized): 0.065
#   재방문 (normalized): 0.065
#   속도 (normalized): 0.716
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 1361137881, 가게 이름: 채석강
# 점수 (정규화 전):
#   가성비: -0.4149377593360996
#   청결도: 4.979253112033195
#   재방문: 2.4896265560165975
#   속도: -1.2448132780082988
#   분위기: 1.6597510373443984
# 정규화된 점수:
#   가성비 (normalized): 0.343
#   청결도 (normalized): 0.116
#   재방문 (normalized): 0.055
#   속도 (normalized): 0.584
#   분위기 (normalized): 0.18
# ----------------------------------------
# 가게 ID: 1420055829, 가게 이름: 임병주산동칼국수
# 점수 (정규화 전):
#   가성비: -17.586206896551722
#   청결도: 0.0
#   재방문: 0.0
#   속도: -0.3448275862068966
#   분위기: -0.6896551724137931
# 정규화된 점수:
#   가성비 (normalized): 0.128
#   청결도 (normalized): 0.071
#   재방문 (normalized): 0.033
#   속도 (normalized): 0.644
#   분위기 (normalized): 0.118
# ----------------------------------------
# 가게 ID: 1931613846, 가게 이름: 우나유 나고야식 장어덮밥
# 점수 (정규화 전):
#   가성비: -5.5
#   청결도: 4.5
#   재방문: 12.0
#   속도: -1.0
#   분위기: 6.5
# 정규화된 점수:
#   가성비 (normalized): 0.279
#   청결도 (normalized): 0.112
#   재방문 (normalized): 0.138
#   속도 (normalized): 0.6
#   분위기 (normalized): 0.308
# ----------------------------------------
# 가게 ID: 36200001, 가게 이름: 춘향골남원추어탕 서초점
# 점수 (정규화 전):
#   가성비: 0.7246376811594203
#   청결도: 0.7246376811594203
#   재방문: 1.4492753623188406
#   속도: 0.0
#   분위기: 0.0
# 정규화된 점수:
#   가성비 (normalized): 0.357
#   청결도 (normalized): 0.078
#   재방문 (normalized): 0.046
#   속도 (normalized): 0.667
#   분위기 (normalized): 0.136
# ----------------------------------------
# 가게 ID: 13150444, 가게 이름: 난랑
# 점수 (정규화 전):
#   가성비: -3.4482758620689653
#   청결도: 2.413793103448276
#   재방문: 5.172413793103448
#   속도: 1.0344827586206897
#   분위기: 2.413793103448276
# 정규화된 점수:
#   가성비 (normalized): 0.305
#   청결도 (normalized): 0.093
#   재방문 (normalized): 0.078
#   속도 (normalized): 0.736
#   분위기 (normalized): 0.2
# ----------------------------------------

# %%
# 결과 저장 (새로운 파일에 저장)
with open('/content/drive/MyDrive/NaverCrawlingData/final_final_final_final_dataset.json', 'w', encoding='utf-8') as f:
    json.dump(final_dataset, f, ensure_ascii=False, indent=4)

print("항목별로 정규화된 점수를 포함한 새로운 데이터셋이 저장되었습니다.")
# Out:
# 항목별로 정규화된 점수를 포함한 새로운 데이터셋이 저장되었습니다.

# %%
import pandas as pd

# final_final_final_final_dataset.json 파일 로드
with open('/content/drive/MyDrive/NaverCrawlingData/final_final_final_final_dataset.json', 'r') as f:
    data = json.load(f)

# 가게별 점수를 추출하여 DataFrame으로 변환
store_data = []
for store in data:
    store_id = store['store_id']
    store_name = store['store_info']['store_name']
    scores = store['store_info']['scores']
    store_data.append({
        'store_id': store_id,
        'store_name': store_name,
        '가성비': scores['가성비'],
        '청결도': scores['청결도'],
        '재방문': scores['재방문'],
        '속도': scores['속도'],
        '분위기': scores['분위기']
    })

df_scores = pd.DataFrame(store_data)
df_scores
# Out:
#        store_id       store_name        가성비         청결도         재방문        속도  \
# 0    1582818366         퀸즈가든 양재점  35.000000   14.375000   16.875000 -2.500000
# 1      37233088        갈비사랑 양재본점 -27.777778   12.222222    8.888889 -6.666667
# 2      38264349            한양돈까스  -7.500000   -1.250000    0.000000 -3.333333
# 3    1113983640  탐라순대국감자탕 양재역직영점  52.000000  104.000000  110.000000  2.000000
# 4      32254662          한국순대 본점 -11.111111    0.370370    2.962963 -2.222222
# ..          ...              ...        ...         ...         ...       ...
# 130  1361137881              채석강  -0.414938    4.979253    2.489627 -1.244813
# 131  1420055829         임병주산동칼국수 -17.586207    0.000000    0.000000 -0.344828
# 132  1931613846    우나유 나고야식 장어덮밥  -5.500000    4.500000   12.000000 -1.000000
# 133    36200001     춘향골남원추어탕 서초점   0.724638    0.724638    1.449275  0.000000
# 134    13150444               난랑  -3.448276    2.413793    5.172414  1.034483
#
#            분위기
# 0     0.000000
# 1    12.222222
# 2     0.000000
# 3    12.000000
# 4     1.851852
# ..         ...
# 130   1.659751
# 131  -0.689655
# 132   6.500000
# 133   0.000000
# 134   2.413793
#
# [135 rows x 7 columns]

# %%
# 특정 측면(예: 가성비)에 대해 순위를 매기기
sorted_by_price = df_scores.sort_values(by='가성비', ascending=False)

# 결과 출력
sorted_by_price
# Out:
#        store_id        store_name        가성비         청결도         재방문  \
# 3    1113983640   탐라순대국감자탕 양재역직영점  52.000000  104.000000  110.000000
# 124  1113983640   탐라순대국감자탕 양재역직영점  52.000000  104.000000  110.000000
# 122  1932467805  보글이 생태탕왕코다리 양재역점  35.714286    8.214286   10.000000
# 75   1034622849               국고집  35.483871    6.774194   16.774194
# 0    1582818366          퀸즈가든 양재점  35.000000   14.375000   16.875000
# ..          ...               ...        ...         ...         ...
# 131  1420055829          임병주산동칼국수 -17.586207    0.000000    0.000000
# 91     38643869          양지수제샌드위치 -18.181818    2.020202    0.000000
# 70   1786476142            로마옥 도곡 -18.181818    3.636364   12.727273
# 63   1944962798     이가네양꼬치 양재역직영점 -21.111111    2.222222    5.185185
# 1      37233088         갈비사랑 양재본점 -27.777778   12.222222    8.888889
#
#            속도        분위기
# 3    2.000000  12.000000
# 124  2.000000  12.000000
# 122 -0.357143   2.500000
# 75   0.967742  -5.161290
# 0   -2.500000   0.000000
# ..        ...        ...
# 131 -0.344828  -0.689655
# 91  -1.010101   6.060606
# 70  -3.636364  32.727273
# 63  -1.111111   1.851852
# 1   -6.666667  12.222222
#
# [135 rows x 7 columns]

# %%
# 파일로 저장하려면:
sorted_by_price.to_csv('/content/drive/MyDrive/NaverCrawlingData/store_ranking_by_price.csv', index=False)
